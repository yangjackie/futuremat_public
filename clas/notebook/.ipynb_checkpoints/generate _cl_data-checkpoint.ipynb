# %% [markdown]
# # Generate data for CLAS analysis

# %% [markdown]
# Here we demonstrate how to create the dataset for CLAS processes.

# %% [markdown]
# To run the code from scratch, you should first download the information of inorganic active materials from Materials Project using the command line tool called get_structure.py. A sample execution command is shown below:
#
# ```
# python3 get_structure.py compounds H 1 --stable
# ```
#
# In this demo, I am using binary MH-CL (redox materials: M-H/M-H-N) as an example. I have already prepared the materials information under: data/binary.

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('../..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from clas.construct_cl import GibbsChemicalReactionLoop
from clas.construct_cl import chemical_looping_entries
from pathlib import Path
import json
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Define the subreactions in MH-CL

# %%
mh_cl = [{"reactant_entries": "nit_hydrides",
           "product_entries": "hydrides",
           "gaseous_reactants": ["H2"],
           "gaseous_products": ["NH3"],
           "possible_yields": []
          },
          {"reactant_entries":"hydrides",
           "product_entries":"nit_hydrides",
           "gaseous_reactants":["N2"],
           "gaseous_products":[],
           "possible_yields":["H2"]
          }]

# %%
input_cl_list = chemical_looping_entries(mh_cl, "binary")
# Out:
# Current database version:  2021.11.10
# Retrieving ThermoDoc documents:   0%|          | 0/175 [00:00<?, ?it/s]
# Retrieving ThermoDoc documents:   0%|          | 0/65 [00:00<?, ?it/s]
# Retrieving ThermoDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving ThermoDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# Retrieving ThermoDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
input_cl_list[0]
# Out:
# {'reactant_entries': [mp-1187172 ComputedStructureEntry - Sr4 H4 N4    (SrHN)
#   Energy (Uncorrected)     = -61.7492  eV (-5.1458  eV/atom)
#   Correction               = -1.4440   eV (-0.1203  eV/atom)
#   Energy (Final)           = -63.1932  eV (-5.2661  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (N): -1.4440   eV (-0.1203  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE Sr_sv 07Sep2000', 'hash': 'ca6a5429c120a0ab705824386a76fe5b'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}, {'titel': 'PAW_PBE N 08Apr2002', 'hash': 'b98fd027ddebc67da4063ff2cabbc04b'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2020-05-03 00:29:40.257000
#     task_id                = mp-1427076
#     oxidation_states       = {'Sr': 2.0, 'H': 1.0, 'N': -3.0}
#     run_type               = GGA,
#   mp-1188715 ComputedStructureEntry - Zn1 H8 N10   (Zn(H4N5)2)
#   Energy (Uncorrected)     = -110.8993 eV (-5.8368  eV/atom)
#   Correction               = -3.6100   eV (-0.1900  eV/atom)
#   Energy (Final)           = -114.5093 eV (-6.0268  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (N): -3.6100   eV (-0.1900  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE Zn 06Sep2000', 'hash': 'e35ee27f8483a63bb68dbc236a343af3'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}, {'titel': 'PAW_PBE N 08Apr2002', 'hash': 'b98fd027ddebc67da4063ff2cabbc04b'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2021-02-07 07:30:04.530000
#     task_id                = mp-1882884
#     oxidation_states       = {'Zn': 2.0, 'H': 1.0, 'N': -1.0}
#     run_type               = GGA,
#   mp-1200910 ComputedStructureEntry - Li28 H20 N16 (Li7H5N4)
#   Energy (Uncorrected)     = -286.9325 eV (-4.4833  eV/atom)
#   Correction               = -5.7760   eV (-0.0902  eV/atom)
#   Energy (Final)           = -292.7085 eV (-4.5736  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (N): -5.7760   eV (-0.0902  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE Li_sv 10Sep2004', 'hash': '8245d7383d7556214082aa40a887cd96'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}, {'titel': 'PAW_PBE N 08Apr2002', 'hash': 'b98fd027ddebc67da4063ff2cabbc04b'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2020-04-30 00:44:56.391000
#     task_id                = mp-1328027
#     oxidation_states       = {'Li': 1.0, 'H': 1.0, 'N': -3.0}
#     run_type               = GGA,
#   mp-28018 ComputedStructureEntry - Be16 H64 N32 (Be(H2N)2)
#   Energy (Uncorrected)     = -607.6353 eV (-5.4253  eV/atom)
#   Correction               = -11.5520  eV (-0.1031  eV/atom)
#   Energy (Final)           = -619.1873 eV (-5.5285  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (N): -11.5520  eV (-0.1031  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE Be_sv 06Sep2000', 'hash': 'f933a35dc70f32d8c3eff76a4b66cf7d'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}, {'titel': 'PAW_PBE N 08Apr2002', 'hash': 'b98fd027ddebc67da4063ff2cabbc04b'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2021-02-08 12:39:18.101000
#     task_id                = mp-1895923
#     oxidation_states       = {'Be': 2.0, 'H': 1.0, 'N': -3.0}
#     run_type               = GGA,
#   mp-29306 ComputedStructureEntry - B20 H16 N8   (B5(H2N)2)
#   Energy (Uncorrected)     = -256.4268 eV (-5.8279  eV/atom)
#   Correction               = -5.7520   eV (-0.1307  eV/atom)
#   Energy (Final)           = -262.1788 eV (-5.9586  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (H): -2.8640   eV (-0.0651  eV/atom)
#     MP2020 anion correction (N): -2.8880   eV (-0.0656  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE B 06Sep2000', 'hash': '18ed2875dfa6305324cec3d7d59273ae'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}, {'titel': 'PAW_PBE N 08Apr2002', 'hash': 'b98fd027ddebc67da4063ff2cabbc04b'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2020-04-30 12:35:41.376000
#     task_id                = mp-1347079
#     oxidation_states       = {'B': 1.2, 'H': -1.0, 'N': -1.0}
#     run_type               = GGA,
#   mp-675153 ComputedStructureEntry - Ca32 H2 N16  (Ca16HN8)
#   Energy (Uncorrected)     = -241.2605 eV (-4.8252  eV/atom)
#   Correction               = -5.7760   eV (-0.1155  eV/atom)
#   Energy (Final)           = -247.0365 eV (-4.9407  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (N): -5.7760   eV (-0.1155  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE Ca_sv 06Sep2000', 'hash': 'eb006721e214c04b3c13146e81b3a27d'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}, {'titel': 'PAW_PBE N 08Apr2002', 'hash': 'b98fd027ddebc67da4063ff2cabbc04b'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2020-04-29 23:40:27.747000
#     task_id                = mp-1324424
#     oxidation_states       = {}
#     run_type               = GGA,
#   mp-697139 ComputedStructureEntry - P4 H4 N8     (PHN2)
#   Energy (Uncorrected)     = -107.8649 eV (-6.7416  eV/atom)
#   Correction               = -2.8880   eV (-0.1805  eV/atom)
#   Energy (Final)           = -110.7529 eV (-6.9221  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (N): -2.8880   eV (-0.1805  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE P 17Jan2003', 'hash': '7dc3393307131ae67785a0cdacb61d5f'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}, {'titel': 'PAW_PBE N 08Apr2002', 'hash': 'b98fd027ddebc67da4063ff2cabbc04b'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2020-11-11 01:20:17.267000
#     task_id                = mp-1785091
#     oxidation_states       = {'P': 5.0, 'H': 1.0, 'N': -3.0}
#     run_type               = GGA,
#   mp-697144 ComputedStructureEntry - Rb2 H4 N2    (RbH2N)
#   Energy (Uncorrected)     = -34.7738  eV (-4.3467  eV/atom)
#   Correction               = -0.7220   eV (-0.0902  eV/atom)
#   Energy (Final)           = -35.4958  eV (-4.4370  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (N): -0.7220   eV (-0.0902  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE Rb_sv 06Sep2000', 'hash': 'aadc1665275b2ae1eed0dcf93c95f9ce'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}, {'titel': 'PAW_PBE N 08Apr2002', 'hash': 'b98fd027ddebc67da4063ff2cabbc04b'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2020-11-10 20:41:53.445000
#     task_id                = mp-1780722
#     oxidation_states       = {'Rb': 1.0, 'H': 1.0, 'N': -3.0}
#     run_type               = GGA,
#   mp-1195558 ComputedStructureEntry - Zn2 H60 N32  (Zn(H15N8)2)
#   Energy (Uncorrected)     = -496.5004 eV (-5.2819  eV/atom)
#   Correction               = -11.5520  eV (-0.1229  eV/atom)
#   Energy (Final)           = -508.0524 eV (-5.4048  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (N): -11.5520  eV (-0.1229  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE Zn 06Sep2000', 'hash': 'e35ee27f8483a63bb68dbc236a343af3'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}, {'titel': 'PAW_PBE N 08Apr2002', 'hash': 'b98fd027ddebc67da4063ff2cabbc04b'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2021-02-09 13:29:19.207000
#     task_id                = mp-1920548
#     oxidation_states       = {'Zn': 2.0, 'H': 1.0, 'N': -2.0}
#     run_type               = GGA,
#   mp-1201065 ComputedStructureEntry - Li30 H18 N16 (Li15H9N8)
#   Energy (Uncorrected)     = -283.8904 eV (-4.4358  eV/atom)
#   Correction               = -5.7760   eV (-0.0902  eV/atom)
#   Energy (Final)           = -289.6664 eV (-4.5260  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (N): -5.7760   eV (-0.0902  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE Li_sv 10Sep2004', 'hash': '8245d7383d7556214082aa40a887cd96'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}, {'titel': 'PAW_PBE N 08Apr2002', 'hash': 'b98fd027ddebc67da4063ff2cabbc04b'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2020-04-29 18:45:17.945000
#     task_id                = mp-1327891
#     oxidation_states       = {'Li': 1.0, 'H': 1.0, 'N': -3.0}
#     run_type               = GGA,
#   mp-1210462 ComputedStructureEntry - Na8 H8 N8    (NaHN)
#   Energy (Uncorrected)     = -94.2472  eV (-3.9270  eV/atom)
#   Correction               = -2.8880   eV (-0.1203  eV/atom)
#   Energy (Final)           = -97.1352  eV (-4.0473  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (N): -2.8880   eV (-0.1203  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE Na_pv 05Jan2001', 'hash': 'c71d0ed99a871c91fccae9347860d8ba'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}, {'titel': 'PAW_PBE N 08Apr2002', 'hash': 'b98fd027ddebc67da4063ff2cabbc04b'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2021-02-05 00:39:24.903000
#     task_id                = mp-1838739
#     oxidation_states       = {'Na': 1.0, 'H': 1.0, 'N': -2.0}
#     run_type               = GGA,
#   mp-23702 ComputedStructureEntry - Li4 H8 N4    (LiH2N)
#   Energy (Uncorrected)     = -76.1547  eV (-4.7597  eV/atom)
#   Correction               = -1.4440   eV (-0.0902  eV/atom)
#   Energy (Final)           = -77.5987  eV (-4.8499  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (N): -1.4440   eV (-0.0902  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE Li_sv 23Jan2001', 'hash': '4799bab014a83a07c654d7196c8ecfa9'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}, {'titel': 'PAW_PBE N 08Apr2002', 'hash': 'b98fd027ddebc67da4063ff2cabbc04b'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2020-11-12 03:14:55.524000
#     task_id                = mp-1780041
#     oxidation_states       = {'Li': 1.0, 'H': 1.0, 'N': -3.0}
#     run_type               = GGA,
#   mp-27612 ComputedStructureEntry - B8 H56 N16   (BH7N2)
#   Energy (Uncorrected)     = -389.1359 eV (-4.8642  eV/atom)
#   Correction               = -5.7760   eV (-0.0722  eV/atom)
#   Energy (Final)           = -394.9119 eV (-4.9364  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (N): -5.7760   eV (-0.0722  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE B 06Sep2000', 'hash': '18ed2875dfa6305324cec3d7d59273ae'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}, {'titel': 'PAW_PBE N 08Apr2002', 'hash': 'b98fd027ddebc67da4063ff2cabbc04b'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2021-02-08 15:36:23.858000
#     task_id                = mp-1890665
#     oxidation_states       = {'B': 3.0, 'H': 0.42857142857142855, 'N': -3.0}
#     run_type               = GGA,
#   mp-643905 ComputedStructureEntry - Sr4 H16 N8   (Sr(H2N)2)
#   Energy (Uncorrected)     = -143.7695 eV (-5.1346  eV/atom)
#   Correction               = -2.8880   eV (-0.1031  eV/atom)
#   Energy (Final)           = -146.6575 eV (-5.2378  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (N): -2.8880   eV (-0.1031  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE Sr_sv 07Sep2000', 'hash': 'ca6a5429c120a0ab705824386a76fe5b'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}, {'titel': 'PAW_PBE N 08Apr2002', 'hash': 'b98fd027ddebc67da4063ff2cabbc04b'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2020-05-03 19:24:09.181000
#     task_id                = mp-1415642
#     oxidation_states       = {'Sr': 2.0, 'H': 1.0, 'N': -3.0}
#     run_type               = GGA,
#   mp-690794 ComputedStructureEntry - Sr2 H1 N1    (Sr2HN)
#   Energy (Uncorrected)     = -17.5492  eV (-4.3873  eV/atom)
#   Correction               = -0.5400   eV (-0.1350  eV/atom)
#   Energy (Final)           = -18.0892  eV (-4.5223  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (H): -0.1790   eV (-0.0447  eV/atom)
#     MP2020 anion correction (N): -0.3610   eV (-0.0902  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE Sr_sv 07Sep2000', 'hash': 'ca6a5429c120a0ab705824386a76fe5b'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}, {'titel': 'PAW_PBE N 08Apr2002', 'hash': 'b98fd027ddebc67da4063ff2cabbc04b'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2020-11-12 02:49:55.424000
#     task_id                = mp-1798683
#     oxidation_states       = {'Sr': 2.0, 'H': -1.0, 'N': -3.0}
#     run_type               = GGA,
#   mp-733481 ComputedStructureEntry - B32 H40 N4   (B8H10N)
#   Energy (Uncorrected)     = -381.6765 eV (-5.0221  eV/atom)
#   Correction               = -8.6040   eV (-0.1132  eV/atom)
#   Energy (Final)           = -390.2805 eV (-5.1353  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (H): -7.1600   eV (-0.0942  eV/atom)
#     MP2020 anion correction (N): -1.4440   eV (-0.0190  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE B 06Sep2000', 'hash': '18ed2875dfa6305324cec3d7d59273ae'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}, {'titel': 'PAW_PBE N 08Apr2002', 'hash': 'b98fd027ddebc67da4063ff2cabbc04b'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2020-05-01 01:53:01.212000
#     task_id                = mp-1348842
#     oxidation_states       = {'B': 1.625, 'H': -1.0, 'N': -3.0}
#     run_type               = GGA,
#   mp-1103732 ComputedStructureEntry - Yb2 H8 N4    (Yb(H2N)2)
#   Energy (Uncorrected)     = -72.5547  eV (-5.1825  eV/atom)
#   Correction               = -1.4440   eV (-0.1031  eV/atom)
#   Energy (Final)           = -73.9987  eV (-5.2856  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (N): -1.4440   eV (-0.1031  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE Yb_2 06Sep2000', 'hash': '4e60480fd0ebf7ed3d8e835c46e03939'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}, {'titel': 'PAW_PBE N 08Apr2002', 'hash': 'b98fd027ddebc67da4063ff2cabbc04b'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2021-02-10 05:52:13.278000
#     task_id                = mp-1928297
#     oxidation_states       = {'Yb': 2.0, 'H': 1.0, 'N': -3.0}
#     run_type               = GGA,
#   mp-1195097 ComputedStructureEntry - Mn2 H60 N32  (Mn(H15N8)2)
#   Energy (Uncorrected)     = -511.9145 eV (-5.4459  eV/atom)
#   Correction               = -11.5520  eV (-0.1229  eV/atom)
#   Energy (Final)           = -523.4665 eV (-5.5688  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (N): -11.5520  eV (-0.1229  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE Mn_pv 07Sep2000', 'hash': 'fa52f891f234d49bb4cb5ea96aae8f98'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}, {'titel': 'PAW_PBE N 08Apr2002', 'hash': 'b98fd027ddebc67da4063ff2cabbc04b'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2021-03-10 20:36:34.182000
#     task_id                = mp-1983914
#     oxidation_states       = {'Mn': 2.0, 'H': 1.0, 'N': -2.0}
#     run_type               = GGA,
#   mp-1197921 ComputedStructureEntry - H16 S16 N4   (H4S4N)
#   Energy (Uncorrected)     = -157.7229 eV (-4.3812  eV/atom)
#   Correction               = -12.3560  eV (-0.3432  eV/atom)
#   Energy (Final)           = -170.0789 eV (-4.7244  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (S): -8.0480   eV (-0.2236  eV/atom)
#     MP2020 anion correction (H): -2.8640   eV (-0.0796  eV/atom)
#     MP2020 anion correction (N): -1.4440   eV (-0.0401  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}, {'titel': 'PAW_PBE S 17Jan2003', 'hash': 'd368db6899d8839859bbee4811a42a88'}, {'titel': 'PAW_PBE N 08Apr2002', 'hash': 'b98fd027ddebc67da4063ff2cabbc04b'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2021-03-10 23:25:38.035000
#     task_id                = mp-1982637
#     oxidation_states       = {'H': -1.0, 'S': 1.75, 'N': -3.0}
#     run_type               = GGA,
#   mp-1200679 ComputedStructureEntry - B12 H12 N48  (BHN4)
#   Energy (Uncorrected)     = -533.2452 eV (-7.4062  eV/atom)
#   Correction               = -17.3280  eV (-0.2407  eV/atom)
#   Energy (Final)           = -550.5732 eV (-7.6469  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (N): -17.3280  eV (-0.2407  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE B 06Sep2000', 'hash': '18ed2875dfa6305324cec3d7d59273ae'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}, {'titel': 'PAW_PBE N 08Apr2002', 'hash': 'b98fd027ddebc67da4063ff2cabbc04b'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2020-04-29 11:52:01.793000
#     task_id                = mp-1324164
#     oxidation_states       = {'B': 3.0, 'H': 1.0, 'N': -1.0}
#     run_type               = GGA,
#   mp-1200862 ComputedStructureEntry - B6 H24 N2    (B3H12N)
#   Energy (Uncorrected)     = -142.6582 eV (-4.4581  eV/atom)
#   Correction               = -0.7220   eV (-0.0226  eV/atom)
#   Energy (Final)           = -143.3802 eV (-4.4806  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (N): -0.7220   eV (-0.0226  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE B 06Sep2000', 'hash': '18ed2875dfa6305324cec3d7d59273ae'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}, {'titel': 'PAW_PBE N 08Apr2002', 'hash': 'b98fd027ddebc67da4063ff2cabbc04b'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2021-02-09 16:31:25.818000
#     task_id                = mp-1923993
#     oxidation_states       = {'B': -3.0, 'H': 1.0, 'N': -3.0}
#     run_type               = GGA,
#   mp-28143 ComputedStructureEntry - H32 S20 N8   (H8S5N2)
#   Energy (Uncorrected)     = -273.6369 eV (-4.5606  eV/atom)
#   Correction               = -12.9480  eV (-0.2158  eV/atom)
#   Energy (Final)           = -286.5849 eV (-4.7764  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (S): -10.0600  eV (-0.1677  eV/atom)
#     MP2020 anion correction (N): -2.8880   eV (-0.0481  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}, {'titel': 'PAW_PBE S 17Jan2003', 'hash': 'd368db6899d8839859bbee4811a42a88'}, {'titel': 'PAW_PBE N 08Apr2002', 'hash': 'b98fd027ddebc67da4063ff2cabbc04b'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2021-02-07 08:10:44.269000
#     task_id                = mp-1879953
#     oxidation_states       = {'H': 1.0, 'S': -2.0, 'N': 1.0}
#     run_type               = GGA,
#   mp-29491 ComputedStructureEntry - H4 S32 N4    (HS8N)
#   Energy (Uncorrected)     = -176.6917 eV (-4.4173  eV/atom)
#   Correction               = -1.4440   eV (-0.0361  eV/atom)
#   Energy (Final)           = -178.1357 eV (-4.4534  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (N): -1.4440   eV (-0.0361  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}, {'titel': 'PAW_PBE S 17Jan2003', 'hash': 'd368db6899d8839859bbee4811a42a88'}, {'titel': 'PAW_PBE N 08Apr2002', 'hash': 'b98fd027ddebc67da4063ff2cabbc04b'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2021-02-05 14:03:40.839000
#     task_id                = mp-1844261
#     oxidation_states       = {'H': 1.0, 'S': 0.0, 'N': -1.0}
#     run_type               = GGA,
#   mp-675452 ComputedStructureEntry - Ti20 H2 N17  (Ti20H2N17)
#   Energy (Uncorrected)     = -367.9317 eV (-9.4341  eV/atom)
#   Correction               = -6.4950   eV (-0.1665  eV/atom)
#   Energy (Final)           = -374.4267 eV (-9.6007  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (H): -0.3580   eV (-0.0092  eV/atom)
#     MP2020 anion correction (N): -6.1370   eV (-0.1574  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE Ti_pv 07Sep2000', 'hash': '70bc3ea8bf68f10e7e1e4721bb91972a'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}, {'titel': 'PAW_PBE N 08Apr2002', 'hash': 'b98fd027ddebc67da4063ff2cabbc04b'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2020-04-30 15:23:16.769000
#     task_id                = mp-1360571
#     oxidation_states       = {'Ti': 2.6, 'H': -1.0, 'N': -2.9411764705882355}
#     run_type               = GGA,
#   mp-1181459 ComputedStructureEntry - H48 S8 N16   (H6SN2)
#   Energy (Uncorrected)     = -332.9925 eV (-4.6249  eV/atom)
#   Correction               = -9.8000   eV (-0.1361  eV/atom)
#   Energy (Final)           = -342.7925 eV (-4.7610  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (S): -4.0240   eV (-0.0559  eV/atom)
#     MP2020 anion correction (N): -5.7760   eV (-0.0802  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}, {'titel': 'PAW_PBE S 17Jan2003', 'hash': 'd368db6899d8839859bbee4811a42a88'}, {'titel': 'PAW_PBE N 08Apr2002', 'hash': 'b98fd027ddebc67da4063ff2cabbc04b'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2021-02-07 10:15:29.131000
#     task_id                = mp-1877387
#     oxidation_states       = {'H': 1.0, 'S': -1.0, 'N': -2.5}
#     run_type               = GGA,
#   mp-1197839 ComputedStructureEntry - B16 H64 N8   (B2H8N)
#   Energy (Uncorrected)     = -409.7752 eV (-4.6565  eV/atom)
#   Correction               = -2.8880   eV (-0.0328  eV/atom)
#   Energy (Final)           = -412.6632 eV (-4.6894  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (N): -2.8880   eV (-0.0328  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE B 06Sep2000', 'hash': '18ed2875dfa6305324cec3d7d59273ae'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}, {'titel': 'PAW_PBE N 08Apr2002', 'hash': 'b98fd027ddebc67da4063ff2cabbc04b'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2021-02-09 07:15:11.046000
#     task_id                = mp-1886845
#     oxidation_states       = {'B': -3.0, 'H': 1.0, 'N': -2.0}
#     run_type               = GGA,
#   mp-1210795 ComputedStructureEntry - Li6 H4 N4    (Li3(HN)2)
#   Energy (Uncorrected)     = -62.3652  eV (-4.4547  eV/atom)
#   Correction               = -1.4440   eV (-0.1031  eV/atom)
#   Energy (Final)           = -63.8092  eV (-4.5578  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (N): -1.4440   eV (-0.1031  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE Li_sv 23Jan2001', 'hash': '4799bab014a83a07c654d7196c8ecfa9'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}, {'titel': 'PAW_PBE N 08Apr2002', 'hash': 'b98fd027ddebc67da4063ff2cabbc04b'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2021-02-07 04:12:47.805000
#     task_id                = mp-1864421
#     oxidation_states       = {'Li': 1.0, 'H': 1.0, 'N': -2.5}
#     run_type               = GGA,
#   mp-28686 ComputedStructureEntry - Ni18 H72 N36 (Ni(H2N)2)
#   Energy (Uncorrected)     = -674.3731 eV (-5.3522  eV/atom)
#   Correction               = -12.9960  eV (-0.1031  eV/atom)
#   Energy (Final)           = -687.3691 eV (-5.4553  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (N): -12.9960  eV (-0.1031  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE Ni_pv 06Sep2000', 'hash': '252a974c7f603c1f24e30fd36a0dba30'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}, {'titel': 'PAW_PBE N 08Apr2002', 'hash': 'b98fd027ddebc67da4063ff2cabbc04b'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2020-05-02 02:42:38.569000
#     task_id                = mp-1366164
#     oxidation_states       = {'Ni': 2.0, 'H': 1.0, 'N': -3.0}
#     run_type               = GGA,
#   mp-29349 ComputedStructureEntry - H16 S16 N16  (HSN)
#   Energy (Uncorrected)     = -248.0858 eV (-5.1685  eV/atom)
#   Correction               = -5.7760   eV (-0.1203  eV/atom)
#   Energy (Final)           = -253.8618 eV (-5.2888  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (N): -5.7760   eV (-0.1203  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}, {'titel': 'PAW_PBE S 17Jan2003', 'hash': 'd368db6899d8839859bbee4811a42a88'}, {'titel': 'PAW_PBE N 08Apr2002', 'hash': 'b98fd027ddebc67da4063ff2cabbc04b'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2021-02-09 05:11:43.405000
#     task_id                = mp-1884156
#     oxidation_states       = {'H': 1.0, 'S': 2.0, 'N': -3.0}
#     run_type               = GGA,
#   mp-530696 ComputedStructureEntry - Ca40 H15 N20 (Ca8H3N4)
#   Energy (Uncorrected)     = -355.1883 eV (-4.7358  eV/atom)
#   Correction               = -7.2200   eV (-0.0963  eV/atom)
#   Energy (Final)           = -362.4083 eV (-4.8321  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (N): -7.2200   eV (-0.0963  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE Ca_sv 06Sep2000', 'hash': 'eb006721e214c04b3c13146e81b3a27d'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}, {'titel': 'PAW_PBE N 08Apr2002', 'hash': 'b98fd027ddebc67da4063ff2cabbc04b'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = False
#     last_updated           = 2014-03-05 15:53:31
#     task_id                = mp-531401
#     oxidation_states       = {}
#     run_type               = GGA,
#   mp-604337 ComputedStructureEntry - Cd8 H32 N64  (Cd(HN2)4)
#   Energy (Uncorrected)     = -632.2284 eV (-6.0791  eV/atom)
#   Correction               = -23.1040  eV (-0.2222  eV/atom)
#   Energy (Final)           = -655.3324 eV (-6.3013  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (N): -23.1040  eV (-0.2222  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE Cd 06Sep2000', 'hash': '0506b2d0ac28d5fe2b5ced77a701aa86'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}, {'titel': 'PAW_PBE N 08Apr2002', 'hash': 'b98fd027ddebc67da4063ff2cabbc04b'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2020-04-30 04:47:25.224000
#     task_id                = mp-1325574
#     oxidation_states       = {'Cd': 2.0, 'H': 1.0, 'N': -0.75}
#     run_type               = GGA,
#   mp-644307 ComputedStructureEntry - Ca4 H16 N8   (Ca(H2N)2)
#   Energy (Uncorrected)     = -145.7746 eV (-5.2062  eV/atom)
#   Correction               = -2.8880   eV (-0.1031  eV/atom)
#   Energy (Final)           = -148.6626 eV (-5.3094  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (N): -2.8880   eV (-0.1031  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE Ca_sv 06Sep2000', 'hash': 'eb006721e214c04b3c13146e81b3a27d'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}, {'titel': 'PAW_PBE N 08Apr2002', 'hash': 'b98fd027ddebc67da4063ff2cabbc04b'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2020-05-03 04:25:11.816000
#     task_id                = mp-1425180
#     oxidation_states       = {'Ca': 2.0, 'H': 1.0, 'N': -3.0}
#     run_type               = GGA,
#   mp-1196163 ComputedStructureEntry - B12 H40 N4   (B3H10N)
#   Energy (Uncorrected)     = -259.0883 eV (-4.6266  eV/atom)
#   Correction               = -1.4440   eV (-0.0258  eV/atom)
#   Energy (Final)           = -260.5323 eV (-4.6524  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (N): -1.4440   eV (-0.0258  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE B 06Sep2000', 'hash': '18ed2875dfa6305324cec3d7d59273ae'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}, {'titel': 'PAW_PBE N 08Apr2002', 'hash': 'b98fd027ddebc67da4063ff2cabbc04b'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2021-02-08 12:33:20.698000
#     task_id                = mp-1884416
#     oxidation_states       = {'B': -1.0, 'H': 0.6, 'N': -3.0}
#     run_type               = GGA,
#   mp-23850 ComputedStructureEntry - Na4 H8 N4    (NaH2N)
#   Energy (Uncorrected)     = -71.4484  eV (-4.4655  eV/atom)
#   Correction               = -1.4440   eV (-0.0902  eV/atom)
#   Energy (Final)           = -72.8924  eV (-4.5558  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (N): -1.4440   eV (-0.0902  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE Na_pv 05Jan2001', 'hash': 'c71d0ed99a871c91fccae9347860d8ba'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}, {'titel': 'PAW_PBE N 08Apr2002', 'hash': 'b98fd027ddebc67da4063ff2cabbc04b'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2021-02-04 21:06:58.435000
#     task_id                = mp-1829187
#     oxidation_states       = {'Na': 1.0, 'H': 1.0, 'N': -3.0}
#     run_type               = GGA,
#   mp-24026 ComputedStructureEntry - Si6 H18 N2   (Si3H9N)
#   Energy (Uncorrected)     = -113.2724 eV (-4.3566  eV/atom)
#   Correction               = -3.9440   eV (-0.1517  eV/atom)
#   Energy (Final)           = -117.2164 eV (-4.5083  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (H): -3.2220   eV (-0.1239  eV/atom)
#     MP2020 anion correction (N): -0.7220   eV (-0.0278  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE Si 05Jan2001', 'hash': 'b2b0ea6feb62e7cde209616683b8f7f5'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}, {'titel': 'PAW_PBE N 08Apr2002', 'hash': 'b98fd027ddebc67da4063ff2cabbc04b'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2021-02-04 15:04:22.616000
#     task_id                = mp-1836655
#     oxidation_states       = {'Si': 4.0, 'H': -1.0, 'N': -3.0}
#     run_type               = GGA,
#   mp-24383 ComputedStructureEntry - Mg16 H64 N32 (Mg(H2N)2)
#   Energy (Uncorrected)     = -568.9198 eV (-5.0796  eV/atom)
#   Correction               = -11.5520  eV (-0.1031  eV/atom)
#   Energy (Final)           = -580.4718 eV (-5.1828  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (N): -11.5520  eV (-0.1031  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE Mg_pv 06Sep2000', 'hash': 'bbcf6f81cc34a3090d483ad641178746'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}, {'titel': 'PAW_PBE N 08Apr2002', 'hash': 'b98fd027ddebc67da4063ff2cabbc04b'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2021-02-06 08:15:08.574000
#     task_id                = mp-1847421
#     oxidation_states       = {'Mg': 2.0, 'H': 1.0, 'N': -3.0}
#     run_type               = GGA,
#   mp-30228 ComputedStructureEntry - Li8 H2 N2    (Li4HN)
#   Energy (Uncorrected)     = -43.3007  eV (-3.6084  eV/atom)
#   Correction               = -1.0800   eV (-0.0900  eV/atom)
#   Energy (Final)           = -44.3807  eV (-3.6984  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (H): -0.3580   eV (-0.0298  eV/atom)
#     MP2020 anion correction (N): -0.7220   eV (-0.0602  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE Li_sv 23Jan2001', 'hash': '4799bab014a83a07c654d7196c8ecfa9'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}, {'titel': 'PAW_PBE N 08Apr2002', 'hash': 'b98fd027ddebc67da4063ff2cabbc04b'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2020-05-02 09:48:29.297000
#     task_id                = mp-1416959
#     oxidation_states       = {'Li': 1.0, 'H': -1.0, 'N': -3.0}
#     run_type               = GGA,
#   mp-34932 ComputedStructureEntry - Ca1 H1 N1    (CaHN)
#   Energy (Uncorrected)     = -15.9413  eV (-5.3138  eV/atom)
#   Correction               = -0.3610   eV (-0.1203  eV/atom)
#   Energy (Final)           = -16.3023  eV (-5.4341  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (N): -0.3610   eV (-0.1203  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE Ca_sv 06Sep2000', 'hash': 'eb006721e214c04b3c13146e81b3a27d'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}, {'titel': 'PAW_PBE N 08Apr2002', 'hash': 'b98fd027ddebc67da4063ff2cabbc04b'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2020-05-03 12:25:35.140000
#     task_id                = mp-1425346
#     oxidation_states       = {'Ca': 2.0, 'H': 1.0, 'N': -3.0}
#     run_type               = GGA,
#   mp-696812 ComputedStructureEntry - B12 H28 N4   (B3H7N)
#   Energy (Uncorrected)     = -201.2895 eV (-4.5748  eV/atom)
#   Correction               = -1.4440   eV (-0.0328  eV/atom)
#   Energy (Final)           = -202.7335 eV (-4.6076  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (N): -1.4440   eV (-0.0328  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE B 06Sep2000', 'hash': '18ed2875dfa6305324cec3d7d59273ae'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}, {'titel': 'PAW_PBE N 08Apr2002', 'hash': 'b98fd027ddebc67da4063ff2cabbc04b'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2020-05-02 11:35:38.627000
#     task_id                = mp-1376235
#     oxidation_states       = {'B': -1.0, 'H': 0.7142857142857143, 'N': -2.0}
#     run_type               = GGA,
#   mp-703486 ComputedStructureEntry - Mn16 H64 N32 (Mn(H2N)2)
#   Energy (Uncorrected)     = -610.1409 eV (-5.4477  eV/atom)
#   Correction               = -11.5520  eV (-0.1031  eV/atom)
#   Energy (Final)           = -621.6929 eV (-5.5508  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (N): -11.5520  eV (-0.1031  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE Mn_pv 07Sep2000', 'hash': 'fa52f891f234d49bb4cb5ea96aae8f98'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}, {'titel': 'PAW_PBE N 08Apr2002', 'hash': 'b98fd027ddebc67da4063ff2cabbc04b'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2020-08-03 10:02:06.621000
#     task_id                = mp-1771332
#     oxidation_states       = {'Mn': 2.0, 'H': 1.0, 'N': -3.0}
#     run_type               = GGA,
#   mp-1190290 ComputedStructureEntry - B2 H16 N2    (BH8N)
#   Energy (Uncorrected)     = -87.9479  eV (-4.3974  eV/atom)
#   Correction               = -0.7220   eV (-0.0361  eV/atom)
#   Energy (Final)           = -88.6699  eV (-4.4335  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (N): -0.7220   eV (-0.0361  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE B 06Sep2000', 'hash': '18ed2875dfa6305324cec3d7d59273ae'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}, {'titel': 'PAW_PBE N 08Apr2002', 'hash': 'b98fd027ddebc67da4063ff2cabbc04b'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2021-02-10 07:23:44.275000
#     task_id                = mp-1934218
#     oxidation_states       = {'B': -3.0, 'H': 0.75, 'N': -3.0}
#     run_type               = GGA,
#   mp-1185888 ComputedStructureEntry - Mg12 H12 N12 (MgHN)
#   Energy (Uncorrected)     = -182.5261 eV (-5.0702  eV/atom)
#   Correction               = -4.3320   eV (-0.1203  eV/atom)
#   Energy (Final)           = -186.8581 eV (-5.1905  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (N): -4.3320   eV (-0.1203  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE Mg_pv 06Sep2000', 'hash': 'bbcf6f81cc34a3090d483ad641178746'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}, {'titel': 'PAW_PBE N 08Apr2002', 'hash': 'b98fd027ddebc67da4063ff2cabbc04b'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2021-02-05 01:51:42.242000
#     task_id                = mp-1817047
#     oxidation_states       = {'Mg': 2.0, 'H': 1.0, 'N': -3.0}
#     run_type               = GGA,
#   mp-1188579 ComputedStructureEntry - B2 H12 N2    (BH6N)
#   Energy (Uncorrected)     = -75.2444  eV (-4.7028  eV/atom)
#   Correction               = -0.7220   eV (-0.0451  eV/atom)
#   Energy (Final)           = -75.9664  eV (-4.7479  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (N): -0.7220   eV (-0.0451  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE B 06Sep2000', 'hash': '18ed2875dfa6305324cec3d7d59273ae'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}, {'titel': 'PAW_PBE N 08Apr2002', 'hash': 'b98fd027ddebc67da4063ff2cabbc04b'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2020-11-10 20:47:01.674000
#     task_id                = mp-1780111
#     oxidation_states       = {'B': -3.0, 'H': 1.0, 'N': -3.0}
#     run_type               = GGA,
#   mp-1198991 ComputedStructureEntry - Rb6 H24 N10  (Rb3H12N5)
#   Energy (Uncorrected)     = -184.2410 eV (-4.6060  eV/atom)
#   Correction               = -3.6100   eV (-0.0902  eV/atom)
#   Energy (Final)           = -187.8510 eV (-4.6963  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (N): -3.6100   eV (-0.0902  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE Rb_sv 06Sep2000', 'hash': 'aadc1665275b2ae1eed0dcf93c95f9ce'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}, {'titel': 'PAW_PBE N 08Apr2002', 'hash': 'b98fd027ddebc67da4063ff2cabbc04b'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2021-02-10 03:31:11.955000
#     task_id                = mp-1929444
#     oxidation_states       = {'Rb': 1.0, 'H': 1.0, 'N': -3.0}
#     run_type               = GGA,
#   mp-24119 ComputedStructureEntry - Ca8 H4 N4    (Ca2HN)
#   Energy (Uncorrected)     = -75.5594  eV (-4.7225  eV/atom)
#   Correction               = -2.1600   eV (-0.1350  eV/atom)
#   Energy (Final)           = -77.7194  eV (-4.8575  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (H): -0.7160   eV (-0.0447  eV/atom)
#     MP2020 anion correction (N): -1.4440   eV (-0.0902  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE Ca_sv 06Sep2000', 'hash': 'eb006721e214c04b3c13146e81b3a27d'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}, {'titel': 'PAW_PBE N 08Apr2002', 'hash': 'b98fd027ddebc67da4063ff2cabbc04b'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2020-11-10 19:06:59.751000
#     task_id                = mp-1775406
#     oxidation_states       = {'Ca': 2.0, 'H': -1.0, 'N': -3.0}
#     run_type               = GGA,
#   mp-24694 ComputedStructureEntry - Zn16 H64 N32 (Zn(H2N)2)
#   Energy (Uncorrected)     = -539.2019 eV (-4.8143  eV/atom)
#   Correction               = -11.5520  eV (-0.1031  eV/atom)
#   Energy (Final)           = -550.7539 eV (-4.9174  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (N): -11.5520  eV (-0.1031  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE Zn 06Sep2000', 'hash': 'e35ee27f8483a63bb68dbc236a343af3'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}, {'titel': 'PAW_PBE N 08Apr2002', 'hash': 'b98fd027ddebc67da4063ff2cabbc04b'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2021-02-06 05:29:41.764000
#     task_id                = mp-1850084
#     oxidation_states       = {'Zn': 2.0, 'H': 1.0, 'N': -3.0}
#     run_type               = GGA,
#   mp-29475 ComputedStructureEntry - B12 H24 N12  (BH2N)
#   Energy (Uncorrected)     = -287.4733 eV (-5.9890  eV/atom)
#   Correction               = -8.6280   eV (-0.1797  eV/atom)
#   Energy (Final)           = -296.1013 eV (-6.1688  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (H): -4.2960   eV (-0.0895  eV/atom)
#     MP2020 anion correction (N): -4.3320   eV (-0.0902  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE B 06Sep2000', 'hash': '18ed2875dfa6305324cec3d7d59273ae'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}, {'titel': 'PAW_PBE N 08Apr2002', 'hash': 'b98fd027ddebc67da4063ff2cabbc04b'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2021-02-04 08:54:51.582000
#     task_id                = mp-1826609
#     oxidation_states       = {'B': 3.0, 'H': -1.0, 'N': -1.0}
#     run_type               = GGA,
#   mp-31064 ComputedStructureEntry - B12 H20 N2   (B6H10N)
#   Energy (Uncorrected)     = -173.7407 eV (-5.1100  eV/atom)
#   Correction               = -4.3020   eV (-0.1265  eV/atom)
#   Energy (Final)           = -178.0427 eV (-5.2366  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (H): -3.5800   eV (-0.1053  eV/atom)
#     MP2020 anion correction (N): -0.7220   eV (-0.0212  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE B 06Sep2000', 'hash': '18ed2875dfa6305324cec3d7d59273ae'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}, {'titel': 'PAW_PBE N 08Apr2002', 'hash': 'b98fd027ddebc67da4063ff2cabbc04b'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2021-02-05 02:02:44.565000
#     task_id                = mp-1812822
#     oxidation_states       = {'B': 2.0, 'H': -1.0, 'N': -2.0}
#     run_type               = GGA,
#   mp-505451 ComputedStructureEntry - H4 S36 N4    (HS9N)
#   Energy (Uncorrected)     = -193.2457 eV (-4.3919  eV/atom)
#   Correction               = -1.4440   eV (-0.0328  eV/atom)
# ...
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2020-05-03 21:12:07.785000
#     task_id                = mp-1383828
#     oxidation_states       = {}
#     run_type               = GGA,
#   mp-1095024 ComputedStructureEntry - Ti4 H5       (Ti4H5)
#   Energy (Uncorrected)     = -52.0758  eV (-5.7862  eV/atom)
#   Correction               = -0.8950   eV (-0.0994  eV/atom)
#   Energy (Final)           = -52.9708  eV (-5.8856  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (H): -0.8950   eV (-0.0994  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE Ti_pv 07Sep2000', 'hash': '70bc3ea8bf68f10e7e1e4721bb91972a'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2020-05-03 05:45:56.379000
#     task_id                = mp-1400595
#     oxidation_states       = {}
#     run_type               = GGA,
#   mp-1183400 ComputedStructureEntry - Be2 H2       (BeH)
#   Energy (Uncorrected)     = -12.2654  eV (-3.0663  eV/atom)
#   Correction               = -0.3580   eV (-0.0895  eV/atom)
#   Energy (Final)           = -12.6234  eV (-3.1558  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (H): -0.3580   eV (-0.0895  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE Be_sv 06Sep2000', 'hash': 'f933a35dc70f32d8c3eff76a4b66cf7d'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2020-11-12 04:10:55.721000
#     task_id                = mp-1791115
#     oxidation_states       = {}
#     run_type               = GGA,
#   mp-1183656 ComputedStructureEntry - Cd2 H2       (CdH)
#   Energy (Uncorrected)     = -6.7648   eV (-1.6912  eV/atom)
#   Correction               = -0.3580   eV (-0.0895  eV/atom)
#   Energy (Final)           = -7.1228   eV (-1.7807  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (H): -0.3580   eV (-0.0895  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE Cd 06Sep2000', 'hash': '0506b2d0ac28d5fe2b5ced77a701aa86'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2020-05-02 18:47:56.090000
#     task_id                = mp-1425003
#     oxidation_states       = {}
#     run_type               = GGA,
#   mp-1183678 ComputedStructureEntry - Co1 H3       (CoH3)
#   Energy (Uncorrected)     = -16.2726  eV (-4.0682  eV/atom)
#   Correction               = -0.5370   eV (-0.1342  eV/atom)
#   Energy (Final)           = -16.8096  eV (-4.2024  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (H): -0.5370   eV (-0.1342  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE Co 06Sep2000', 'hash': 'b169bca4e137294d2ab3df8cbdd09083'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2020-05-02 14:04:08.914000
#     task_id                = mp-1430826
#     oxidation_states       = {'Co': 3.0, 'H': -1.0}
#     run_type               = GGA,
#   mp-1183993 ComputedStructureEntry - Ga1 H3       (GaH3)
#   Energy (Uncorrected)     = -10.2633  eV (-2.5658  eV/atom)
#   Correction               = -0.5370   eV (-0.1342  eV/atom)
#   Energy (Final)           = -10.8003  eV (-2.7001  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (H): -0.5370   eV (-0.1342  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE Ga_d 06Sep2000', 'hash': '1383ef2b7b4ce0e17391c6cdbd53f51b'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2020-05-03 19:36:05.710000
#     task_id                = mp-1422541
#     oxidation_states       = {'Ga': 3.0, 'H': -1.0}
#     run_type               = GGA,
#   mp-1184606 ComputedStructureEntry - H2 Pt6       (HPt3)
#   Energy (Uncorrected)     = -38.7034  eV (-4.8379  eV/atom)
#   Correction               = -0.3580   eV (-0.0447  eV/atom)
#   Energy (Final)           = -39.0614  eV (-4.8827  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (H): -0.3580   eV (-0.0447  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}, {'titel': 'PAW_PBE Pt 05Jan2001', 'hash': 'a604ea3c6a9cc23c739b762f625cf449'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2020-05-02 16:01:13.647000
#     task_id                = mp-1396067
#     oxidation_states       = {'H': -1.0, 'Pt': 0.3333333333333333}
#     run_type               = GGA,
#   mp-1190750 ComputedStructureEntry - Er6 H18      (ErH3)
#   Energy (Uncorrected)     = -102.8941 eV (-4.2873  eV/atom)
#   Correction               = -3.2220   eV (-0.1343  eV/atom)
#   Energy (Final)           = -106.1161 eV (-4.4215  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (H): -3.2220   eV (-0.1343  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE Er_3 06Sep2000', 'hash': 'daa65a04877317f8c3c593ddeaa8a132'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2021-02-05 11:29:07.354000
#     task_id                = mp-1827537
#     oxidation_states       = {'Er': 3.0, 'H': -1.0}
#     run_type               = GGA,
#   mp-1238837 ComputedStructureEntry - B24 H24      (BH)
#   Energy (Uncorrected)     = -241.0198 eV (-5.0212  eV/atom)
#   Correction               = -4.2960   eV (-0.0895  eV/atom)
#   Energy (Final)           = -245.3158 eV (-5.1107  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (H): -4.2960   eV (-0.0895  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE B 06Sep2000', 'hash': '18ed2875dfa6305324cec3d7d59273ae'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2021-02-04 10:21:36.741000
#     task_id                = mp-1824261
#     oxidation_states       = {'B': 1.0, 'H': -1.0}
#     run_type               = GGA,
#   mp-1338697 ComputedStructureEntry - B40 H72      (B5H9)
#   Energy (Uncorrected)     = -516.9743 eV (-4.6158  eV/atom)
#   Correction               = -12.8880  eV (-0.1151  eV/atom)
#   Energy (Final)           = -529.8623 eV (-4.7309  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (H): -12.8880  eV (-0.1151  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE B 06Sep2000', 'hash': '18ed2875dfa6305324cec3d7d59273ae'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2020-04-29 22:10:05.523000
#     task_id                = mp-1338697
#     oxidation_states       = {'B': 1.8, 'H': -1.0}
#     run_type               = GGA,
#   mp-24728 ComputedStructureEntry - V1 H2        (VH2)
#   Energy (Uncorrected)     = -16.4791  eV (-5.4930  eV/atom)
#   Correction               = -0.3580   eV (-0.1193  eV/atom)
#   Energy (Final)           = -16.8371  eV (-5.6124  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (H): -0.3580   eV (-0.1193  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE V_pv 07Sep2000', 'hash': '7f1297a2e1d963e2a4d81b61f85e4ded'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2020-05-03 13:49:37.794000
#     task_id                = mp-1442122
#     oxidation_states       = {'V': 2.0, 'H': -1.0}
#     run_type               = GGA,
#   mp-29611 ComputedStructureEntry - B40 H64      (B5H8)
#   Energy (Uncorrected)     = -488.7221 eV (-4.6993  eV/atom)
#   Correction               = -11.4560  eV (-0.1102  eV/atom)
#   Energy (Final)           = -500.1781 eV (-4.8094  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (H): -11.4560  eV (-0.1102  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE B 06Sep2000', 'hash': '18ed2875dfa6305324cec3d7d59273ae'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2021-02-05 17:19:16.925000
#     task_id                = mp-1844292
#     oxidation_states       = {'B': 1.6, 'H': -1.0}
#     run_type               = GGA,
#   mp-30529 ComputedStructureEntry - B20 H44      (B5H11)
#   Energy (Uncorrected)     = -285.1491 eV (-4.4555  eV/atom)
#   Correction               = -7.8760   eV (-0.1231  eV/atom)
#   Energy (Final)           = -293.0251 eV (-4.5785  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (H): -7.8760   eV (-0.1231  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE B 06Sep2000', 'hash': '18ed2875dfa6305324cec3d7d59273ae'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2021-02-08 14:17:07.039000
#     task_id                = mp-1905020
#     oxidation_states       = {'B': 2.2, 'H': -1.0}
#     run_type               = GGA,
#   mp-696588 ComputedStructureEntry - P4 H12       (PH3)
#   Energy (Uncorrected)     = -59.7491  eV (-3.7343  eV/atom)
#   Correction               = -2.1480   eV (-0.1342  eV/atom)
#   Energy (Final)           = -61.8971  eV (-3.8686  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (H): -2.1480   eV (-0.1342  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE P 17Jan2003', 'hash': '7dc3393307131ae67785a0cdacb61d5f'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2021-02-05 08:37:44.786000
#     task_id                = mp-1839818
#     oxidation_states       = {'P': 3.0, 'H': -1.0}
#     run_type               = GGA,
#   mp-972237 ComputedStructureEntry - Tc3 H1       (Tc3H)
#   Energy (Uncorrected)     = -31.6171  eV (-7.9043  eV/atom)
#   Correction               = -0.1790   eV (-0.0447  eV/atom)
#   Energy (Final)           = -31.7961  eV (-7.9490  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (H): -0.1790   eV (-0.0447  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE Tc_pv 06Sep2000', 'hash': '781a01d5364a97db83403d98033805b1'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2020-05-03 20:25:37.634000
#     task_id                = mp-1426497
#     oxidation_states       = {'Tc': -0.3333333333333333, 'H': 1.0}
#     run_type               = GGA,
#   mp-973786 ComputedStructureEntry - H3 Pb1       (H3Pb)
#   Energy (Uncorrected)     = -10.7784  eV (-2.6946  eV/atom)
#   Correction               = 0.0000    eV (0.0000   eV/atom)
#   Energy (Final)           = -10.7784  eV (-2.6946  eV/atom)
#   Energy Adjustments:
#     None
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}, {'titel': 'PAW_PBE Pb_d 06Sep2000', 'hash': '8a341c983db1c1cce3afb031df25c667'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2020-05-02 15:23:14.150000
#     task_id                = mp-1431835
#     oxidation_states       = {}
#     run_type               = GGA,
#   mp-975814 ComputedStructureEntry - Mo3 H1       (Mo3H)
#   Energy (Uncorrected)     = -32.3674  eV (-8.0918  eV/atom)
#   Correction               = -0.1790   eV (-0.0447  eV/atom)
#   Energy (Final)           = -32.5464  eV (-8.1366  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (H): -0.1790   eV (-0.0447  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE Mo_pv 08Apr2002', 'hash': '84e18fd84a98e3d7fa8f055952410df0'}, {'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2020-11-11 17:06:37.148000
#     task_id                = mp-1795467
#     oxidation_states       = {}
#     run_type               = GGA],
#  'gaseous_reactants': [mp-24504 ComputedStructureEntry - H4           (H2)
#   Energy (Uncorrected)     = -13.5709  eV (-3.3927  eV/atom)
#   Correction               = 0.0000    eV (0.0000   eV/atom)
#   Energy (Final)           = -13.5709  eV (-3.3927  eV/atom)
#   Energy Adjustments:
#     None
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2020-11-10 21:52:06.206000
#     task_id                = mp-1783195
#     oxidation_states       = {'H': 0.0}
#     run_type               = GGA],
#  'gaseous_products': [mp-29145 ComputedStructureEntry - H12 N4       (H3N)
#   Energy (Uncorrected)     = -79.3776  eV (-4.9611  eV/atom)
#   Correction               = -1.4440   eV (-0.0902  eV/atom)
#   Energy (Final)           = -80.8216  eV (-5.0513  eV/atom)
#   Energy Adjustments:
#     MP2020 anion correction (N): -1.4440   eV (-0.0902  eV/atom)
#   Parameters:
#     potcar_spec            = [{'titel': 'PAW_PBE H 15Jun2001', 'hash': 'bb43c666e3d36577264afe07669e9582'}, {'titel': 'PAW_PBE N 08Apr2002', 'hash': 'b98fd027ddebc67da4063ff2cabbc04b'}]
#     is_hubbard             = False
#     hubbards               = {}
#     run_type               = GGA
#   Data:
#     oxide_type             = None
#     aspherical             = True
#     last_updated           = 2021-02-06 20:28:57.236000
#     task_id                = mp-1877537
#     oxidation_states       = {'H': 1.0, 'N': -3.0}
#     run_type               = GGA],
#  'possible_yields': []}

# %% [markdown]
# First try to construct the CLs at 300 K and calculate the Gibbs reaction energies.

# %%
gibbs_cl = GibbsChemicalReactionLoop(input_cl_list, temp=300)

# %%
gibbs_cl.normalise_to_NH3()

# %%
data = gibbs_cl.parse_to_dict()
data
# Out:
# {'SrHN/SrH2': {'chemical_loop': ['2 H2 + SrHN -> H3N + SrH2',
#    '0.5 N2 + SrH2 -> 0.5 H2 + SrHN'],
#   'rxn_energy': [0.1695, -0.3372],
#   'gf_sisso': [-0.6246, -0.5122],
#   'gf_0k': [-0.7932, -0.6526]},
#  'SrHN/SrH3': {'chemical_loop': ['2.5 H2 + SrHN -> H3N + SrH3',
#    '0.5 N2 + SrH3 -> H2 + SrHN'],
#   'rxn_energy': [1.7579, -1.9256],
#   'gf_sisso': [-0.6246, 0.0129],
#   'gf_0k': [-0.7932, -0.1489]},
#  'Sr2HN/SrH2': {'chemical_loop': ['3 H2 + Sr2HN -> H3N + 2 SrH2',
#    '0.5 N2 + 2 SrH2 -> 1.5 H2 + Sr2HN'],
#   'rxn_energy': [-0.7882, 0.6205],
#   'gf_sisso': [-0.6132, -0.5122],
#   'gf_0k': [-0.7452, -0.6526]},
#  'Sr2HN/SrH3': {'chemical_loop': ['4 H2 + Sr2HN -> H3N + 2 SrH3',
#    '0.5 N2 + 2 SrH3 -> 2.5 H2 + Sr2HN'],
#   'rxn_energy': [2.3886, -2.5563],
#   'gf_sisso': [-0.6132, 0.0129],
#   'gf_0k': [-0.7452, -0.1489]},
#  'Zn(H2N)2/ZnH6': {'chemical_loop': ['2 H2 + 0.5 Zn(H2N)2 -> H3N + 0.5 ZnH6',
#    '0.5 N2 + 0.5 ZnH6 -> 0.5 H2 + 0.5 Zn(H2N)2'],
#   'rxn_energy': [1.1265, -1.2942],
#   'gf_sisso': [-0.2221, 0.1477],
#   'gf_0k': [-0.4169, 0.0289]},
#  'Li7H5N4/LiH': {'chemical_loop': ['1.75 H2 + 0.25 Li7H5N4 -> H3N + 1.75 LiH',
#    '0.5 N2 + 1.75 LiH -> 0.25 H2 + 0.25 Li7H5N4'],
#   'rxn_energy': [0.322, -0.4898],
#   'gf_sisso': [-0.434, -0.3561],
#   'gf_0k': [-0.5941, -0.4955]},
#  'Li15H9N8/LiH': {'chemical_loop': ['1.875 H2 + 0.125 Li15H9N8 -> H3N + 1.875 LiH',
#    '0.5 N2 + 1.875 LiH -> 0.375 H2 + 0.125 Li15H9N8'],
#   'rxn_energy': [0.2335, -0.4012],
#   'gf_sisso': [-0.4341, -0.3561],
#   'gf_0k': [-0.5929, -0.4955]},
#  'Li3(HN)2/LiH': {'chemical_loop': ['1.75 H2 + 0.5 Li3(HN)2 -> H3N + 1.5 LiH',
#    '0.5 N2 + 1.5 LiH -> 0.25 H2 + 0.5 Li3(HN)2'],
#   'rxn_energy': [-0.4503, 0.2825],
#   'gf_sisso': [-0.2245, -0.3561],
#   'gf_0k': [-0.3885, -0.4955]},
#  'Li4HN/LiH': {'chemical_loop': ['3 H2 + Li4HN -> H3N + 4 LiH',
#    '0.5 N2 + 4 LiH -> 1.5 H2 + Li4HN'],
#   'rxn_energy': [-0.8982, 0.7304],
#   'gf_sisso': [-0.3531, -0.3561],
#   'gf_0k': [-0.4709, -0.4955]},
#  'Li2HN/LiH': {'chemical_loop': ['2 H2 + Li2HN -> H3N + 2 LiH',
#    '0.5 N2 + 2 LiH -> 0.5 H2 + Li2HN'],
#   'rxn_energy': [0.1307, -0.2984],
#   'gf_sisso': [-0.4307, -0.3561],
#   'gf_0k': [-0.5836, -0.4955]},
#  'Li3H3N2/LiH': {'chemical_loop': ['1.5 H2 + 0.5 Li3H3N2 -> H3N + 1.5 LiH',
#    '0.5 N2 + 1.5 LiH -> 0.5 Li3H3N2'],
#   'rxn_energy': [0.3382, -0.5059],
#   'gf_sisso': [-0.3936, -0.3561],
#   'gf_0k': [-0.5643, -0.4955]},
#  'B5(H2N)2/B3H4': {'chemical_loop': ['2.167 H2 + 0.5 B5(H2N)2 -> H3N + 0.8333 B3H4',
#    '0.5 N2 + 0.8333 B3H4 -> 0.6667 H2 + 0.5 B5(H2N)2'],
#   'rxn_energy': [0.5781, -0.7458],
#   'gf_sisso': [-0.0789, 0.0534],
#   'gf_0k': [-0.1731, -0.0201]},
#  'B5(H2N)2/BH3': {'chemical_loop': ['4.25 H2 + 0.5 B5(H2N)2 -> H3N + 2.5 BH3',
#    '0.5 N2 + 2.5 BH3 -> 2.75 H2 + 0.5 B5(H2N)2'],
#   'rxn_energy': [-0.0417, -0.126],
#   'gf_sisso': [-0.0789, -0.0308],
#   'gf_0k': [-0.1731, -0.1643]},
#  'B5(H2N)2/B7H10': {'chemical_loop': ['2.286 H2 + 0.5 B5(H2N)2 -> H3N + 0.3571 B7H10',
#    '0.5 N2 + 0.3571 B7H10 -> 0.7857 H2 + 0.5 B5(H2N)2'],
#   'rxn_energy': [-0.0191, -0.1487],
#   'gf_sisso': [-0.0789, -0.047],
#   'gf_0k': [-0.1731, -0.1549]},
#  'B5(H2N)2/B5H7': {'chemical_loop': ['2.25 H2 + 0.5 B5(H2N)2 -> H3N + 0.5 B5H7',
#    '0.5 N2 + 0.5 B5H7 -> 0.75 H2 + 0.5 B5(H2N)2'],
#   'rxn_energy': [-0.1757, 0.008],
#   'gf_sisso': [-0.0789, -0.0737],
#   'gf_0k': [-0.1731, -0.1872]},
#  'B5(H2N)2/B10H13': {'chemical_loop': ['2.125 H2 + 0.5 B5(H2N)2 -> H3N + 0.25 B10H13',
#    '0.5 N2 + 0.25 B10H13 -> 0.625 H2 + 0.5 B5(H2N)2'],
#   'rxn_energy': [-0.1887, 0.0209],
#   'gf_sisso': [-0.0789, -0.0791],
#   'gf_0k': [-0.1731, -0.1827]},
#  'B5(H2N)2/B5H4': {'chemical_loop': ['1.5 H2 + 0.5 B5(H2N)2 -> H3N + 0.5 B5H4',
#    '0.5 N2 + 0.5 B5H4 -> 0.5 B5(H2N)2'],
#   'rxn_energy': [1.166, -1.3337],
#   'gf_sisso': [-0.0789, 0.1999],
#   'gf_0k': [-0.1731, 0.1727]},
#  'B5(H2N)2/B2H5': {'chemical_loop': ['3.625 H2 + 0.5 B5(H2N)2 -> H3N + 1.25 B2H5',
#    '0.5 N2 + 1.25 B2H5 -> 2.125 H2 + 0.5 B5(H2N)2'],
#   'rxn_energy': [-0.1676, -0.0001],
#   'gf_sisso': [-0.0789, -0.0496],
#   'gf_0k': [-0.1731, -0.1793]},
#  'B5(H2N)2/B2H3': {'chemical_loop': ['2.375 H2 + 0.5 B5(H2N)2 -> H3N + 1.25 B2H3',
#    '0.5 N2 + 1.25 B2H3 -> 0.875 H2 + 0.5 B5(H2N)2'],
#   'rxn_energy': [-0.0184, -0.1493],
#   'gf_sisso': [-0.0789, -0.0456],
#   'gf_0k': [-0.1731, -0.1516]},
#  'B5(H2N)2/B9H11': {'chemical_loop': ['2.028 H2 + 0.5 B5(H2N)2 -> H3N + 0.2778 B9H11',
#    '0.5 N2 + 0.2778 B9H11 -> 0.5278 H2 + 0.5 B5(H2N)2'],
#   'rxn_energy': [-0.2269, 0.0592],
#   'gf_sisso': [-0.0789, -0.0888],
#   'gf_0k': [-0.1731, -0.189]},
#  'B5(H2N)2/B3H5': {'chemical_loop': ['2.583 H2 + 0.5 B5(H2N)2 -> H3N + 0.8333 B3H5',
#    '0.5 N2 + 0.8333 B3H5 -> 1.083 H2 + 0.5 B5(H2N)2'],
#   'rxn_energy': [-0.132, -0.0357],
#   'gf_sisso': [-0.0789, -0.0598],
#   'gf_0k': [-0.1731, -0.1731]},
#  'B5(H2N)2/B13H19': {'chemical_loop': ['2.327 H2 + 0.5 B5(H2N)2 -> H3N + 0.1923 B13H19',
#    '0.5 N2 + 0.1923 B13H19 -> 0.8269 H2 + 0.5 B5(H2N)2'],
#   'rxn_energy': [-0.0651, -0.1026],
#   'gf_sisso': [-0.0789, -0.0539],
#   'gf_0k': [-0.1731, -0.16]},
#  'B5(H2N)2/B4H5': {'chemical_loop': ['2.063 H2 + 0.5 B5(H2N)2 -> H3N + 0.625 B4H5',
#    '0.5 N2 + 0.625 B4H5 -> 0.5625 H2 + 0.5 B5(H2N)2'],
#   'rxn_energy': [-0.1815, 0.0138],
#   'gf_sisso': [-0.0789, -0.0796],
#   'gf_0k': [-0.1731, -0.1764]},
#  'B5(H2N)2/BH': {'chemical_loop': ['1.75 H2 + 0.5 B5(H2N)2 -> H3N + 2.5 BH',
#    '0.5 N2 + 2.5 BH -> 0.25 H2 + 0.5 B5(H2N)2'],
#   'rxn_energy': [0.3251, -0.4928],
#   'gf_sisso': [-0.0789, 0.0117],
#   'gf_0k': [-0.1731, -0.0747]},
#  'B5(H2N)2/B5H9': {'chemical_loop': ['2.75 H2 + 0.5 B5(H2N)2 -> H3N + 0.5 B5H9',
#    '0.5 N2 + 0.5 B5H9 -> 1.25 H2 + 0.5 B5(H2N)2'],
#   'rxn_energy': [-0.1042, -0.0636],
#   'gf_sisso': [-0.0789, -0.0529],
#   'gf_0k': [-0.1731, -0.1644]},
#  'B5(H2N)2/B5H8': {'chemical_loop': ['2.5 H2 + 0.5 B5(H2N)2 -> H3N + 0.5 B5H8',
#    '0.5 N2 + 0.5 B5H8 -> H2 + 0.5 B5(H2N)2'],
#   'rxn_energy': [-0.0248, -0.1429],
#   'gf_sisso': [-0.0789, -0.0448],
#   'gf_0k': [-0.1731, -0.1526]},
#  'B5(H2N)2/B5H11': {'chemical_loop': ['3.25 H2 + 0.5 B5(H2N)2 -> H3N + 0.5 B5H11',
#    '0.5 N2 + 0.5 B5H11 -> 1.75 H2 + 0.5 B5(H2N)2'],
#   'rxn_energy': [-0.0438, -0.1239],
#   'gf_sisso': [-0.0789, -0.0388],
#   'gf_0k': [-0.1731, -0.1587]},
#  'B8H10N/B3H4': {'chemical_loop': ['1.833 H2 + B8H10N -> H3N + 2.667 B3H4',
#    '0.5 N2 + 2.667 B3H4 -> 0.3333 H2 + B8H10N'],
#   'rxn_energy': [1.0034, -1.1711],
#   'gf_sisso': [-0.0091, 0.0534],
#   'gf_0k': [-0.0985, -0.0201]},
#  'B8H10N/BH3': {'chemical_loop': ['8.5 H2 + B8H10N -> H3N + 8 BH3',
#    '0.5 N2 + 8 BH3 -> 7 H2 + B8H10N'],
#   'rxn_energy': [-0.98, 0.8122],
#   'gf_sisso': [-0.0091, -0.0308],
#   'gf_0k': [-0.0985, -0.1643]},
#  'B8H10N/B7H10': {'chemical_loop': ['2.214 H2 + B8H10N -> H3N + 1.143 B7H10',
#    '0.5 N2 + 1.143 B7H10 -> 0.7143 H2 + B8H10N'],
#   'rxn_energy': [-0.9075, 0.7398],
#   'gf_sisso': [-0.0091, -0.047],
#   'gf_0k': [-0.0985, -0.1549]},
#  'B8H10N/B5H7': {'chemical_loop': ['2.1 H2 + B8H10N -> H3N + 1.6 B5H7',
#    '0.5 N2 + 1.6 B5H7 -> 0.6 H2 + B8H10N'],
#   'rxn_energy': [-1.4088, 1.241],
#   'gf_sisso': [-0.0091, -0.0737],
#   'gf_0k': [-0.0985, -0.1872]},
#  'B8H10N/B10H13': {'chemical_loop': ['1.7 H2 + B8H10N -> H3N + 0.8 B10H13',
#    '0.5 N2 + 0.8 B10H13 -> 0.2 H2 + B8H10N'],
#   'rxn_energy': [-1.4502, 1.2825],
#   'gf_sisso': [-0.0091, -0.0791],
#   'gf_0k': [-0.0985, -0.1827]},
#  'B8H10N/B2H5': {'chemical_loop': ['6.5 H2 + B8H10N -> H3N + 4 B2H5',
#    '0.5 N2 + 4 B2H5 -> 5 H2 + B8H10N'],
#   'rxn_energy': [-1.383, 1.2153],
#   'gf_sisso': [-0.0091, -0.0496],
#   'gf_0k': [-0.0985, -0.1793]},
#  'B8H10N/B2H3': {'chemical_loop': ['2.5 H2 + B8H10N -> H3N + 4 B2H3',
#    '0.5 N2 + 4 B2H3 -> H2 + B8H10N'],
#   'rxn_energy': [-0.9055, 0.7378],
#   'gf_sisso': [-0.0091, -0.0456],
#   'gf_0k': [-0.0985, -0.1516]},
#  'B8H10N/B3H5': {'chemical_loop': ['3.167 H2 + B8H10N -> H3N + 2.667 B3H5',
#    '0.5 N2 + 2.667 B3H5 -> 1.667 H2 + B8H10N'],
#   'rxn_energy': [-1.269, 1.1012],
#   'gf_sisso': [-0.0091, -0.0598],
#   'gf_0k': [-0.0985, -0.1731]},
#  'B8H10N/B13H19': {'chemical_loop': ['2.346 H2 + B8H10N -> H3N + 0.6154 B13H19',
#    '0.5 N2 + 0.6154 B13H19 -> 0.8462 H2 + B8H10N'],
#   'rxn_energy': [-1.0549, 0.8872],
#   'gf_sisso': [-0.0091, -0.0539],
#   'gf_0k': [-0.0985, -0.16]},
#  'B8H10N/B4H5': {'chemical_loop': ['1.5 H2 + B8H10N -> H3N + 2 B4H5',
#    '0.5 N2 + 2 B4H5 -> B8H10N'],
#   'rxn_energy': [-1.4275, 1.2597],
#   'gf_sisso': [-0.0091, -0.0796],
#   'gf_0k': [-0.0985, -0.1764]},
#  'B8H10N/B5H9': {'chemical_loop': ['3.7 H2 + B8H10N -> H3N + 1.6 B5H9',
#    '0.5 N2 + 1.6 B5H9 -> 2.2 H2 + B8H10N'],
#   'rxn_energy': [-1.1798, 1.0121],
#   'gf_sisso': [-0.0091, -0.0529],
#   'gf_0k': [-0.0985, -0.1644]},
#  'B8H10N/B5H8': {'chemical_loop': ['2.9 H2 + B8H10N -> H3N + 1.6 B5H8',
#    '0.5 N2 + 1.6 B5H8 -> 1.4 H2 + B8H10N'],
#   'rxn_energy': [-0.9258, 0.7581],
#   'gf_sisso': [-0.0091, -0.0448],
#   'gf_0k': [-0.0985, -0.1526]},
#  'B8H10N/B5H11': {'chemical_loop': ['5.3 H2 + B8H10N -> H3N + 1.6 B5H11',
#    '0.5 N2 + 1.6 B5H11 -> 3.8 H2 + B8H10N'],
#   'rxn_energy': [-0.9868, 0.819],
#   'gf_sisso': [-0.0091, -0.0388],
#   'gf_0k': [-0.0985, -0.1587]},
#  'BHN4/B3H4': {'chemical_loop': ['1.542 H2 + 0.25 BHN4 -> H3N + 0.08333 B3H4',
#    '0.5 N2 + 0.08333 B3H4 -> 0.04167 H2 + 0.25 BHN4'],
#   'rxn_energy': [0.2161, -0.3838],
#   'gf_sisso': [-0.2351, 0.0534],
#   'gf_0k': [-0.4105, -0.0201]},
#  'BHN4/BH3': {'chemical_loop': ['1.75 H2 + 0.25 BHN4 -> H3N + 0.25 BH3',
#    '0.5 N2 + 0.25 BH3 -> 0.25 H2 + 0.25 BHN4'],
#   'rxn_energy': [0.1541, -0.3219],
#   'gf_sisso': [-0.2351, -0.0308],
#   'gf_0k': [-0.4105, -0.1643]},
#  'BHN4/B7H10': {'chemical_loop': ['1.554 H2 + 0.25 BHN4 -> H3N + 0.03571 B7H10',
#    '0.5 N2 + 0.03571 B7H10 -> 0.05357 H2 + 0.25 BHN4'],
#   'rxn_energy': [0.1564, -0.3241],
#   'gf_sisso': [-0.2351, -0.047],
#   'gf_0k': [-0.4105, -0.1549]},
#  'BHN4/B5H7': {'chemical_loop': ['1.55 H2 + 0.25 BHN4 -> H3N + 0.05 B5H7',
#    '0.5 N2 + 0.05 B5H7 -> 0.05 H2 + 0.25 BHN4'],
#   'rxn_energy': [0.1407, -0.3085],
#   'gf_sisso': [-0.2351, -0.0737],
#   'gf_0k': [-0.4105, -0.1872]},
#  'BHN4/B10H13': {'chemical_loop': ['1.537 H2 + 0.25 BHN4 -> H3N + 0.025 B10H13',
#    '0.5 N2 + 0.025 B10H13 -> 0.0375 H2 + 0.25 BHN4'],
#   'rxn_energy': [0.1394, -0.3072],
#   'gf_sisso': [-0.2351, -0.0791],
#   'gf_0k': [-0.4105, -0.1827]},
#  'BHN4/B2H5': {'chemical_loop': ['1.688 H2 + 0.25 BHN4 -> H3N + 0.125 B2H5',
#    '0.5 N2 + 0.125 B2H5 -> 0.1875 H2 + 0.25 BHN4'],
#   'rxn_energy': [0.1415, -0.3093],
#   'gf_sisso': [-0.2351, -0.0496],
#   'gf_0k': [-0.4105, -0.1793]},
#  'BHN4/B2H3': {'chemical_loop': ['1.563 H2 + 0.25 BHN4 -> H3N + 0.125 B2H3',
#    '0.5 N2 + 0.125 B2H3 -> 0.0625 H2 + 0.25 BHN4'],
#   'rxn_energy': [0.1565, -0.3242],
#   'gf_sisso': [-0.2351, -0.0456],
#   'gf_0k': [-0.4105, -0.1516]},
#  'BHN4/B9H11': {'chemical_loop': ['1.528 H2 + 0.25 BHN4 -> H3N + 0.02778 B9H11',
#    '0.5 N2 + 0.02778 B9H11 -> 0.02778 H2 + 0.25 BHN4'],
#   'rxn_energy': [0.1356, -0.3033],
#   'gf_sisso': [-0.2351, -0.0888],
#   'gf_0k': [-0.4105, -0.189]},
#  'BHN4/B3H5': {'chemical_loop': ['1.583 H2 + 0.25 BHN4 -> H3N + 0.08333 B3H5',
#    '0.5 N2 + 0.08333 B3H5 -> 0.08333 H2 + 0.25 BHN4'],
#   'rxn_energy': [0.1451, -0.3128],
#   'gf_sisso': [-0.2351, -0.0598],
#   'gf_0k': [-0.4105, -0.1731]},
#  'BHN4/B13H19': {'chemical_loop': ['1.558 H2 + 0.25 BHN4 -> H3N + 0.01923 B13H19',
#    '0.5 N2 + 0.01923 B13H19 -> 0.05769 H2 + 0.25 BHN4'],
#   'rxn_energy': [0.1518, -0.3195],
#   'gf_sisso': [-0.2351, -0.0539],
#   'gf_0k': [-0.4105, -0.16]},
#  'BHN4/B4H5': {'chemical_loop': ['1.531 H2 + 0.25 BHN4 -> H3N + 0.0625 B4H5',
#    '0.5 N2 + 0.0625 B4H5 -> 0.03125 H2 + 0.25 BHN4'],
#   'rxn_energy': [0.1401, -0.3079],
#   'gf_sisso': [-0.2351, -0.0796],
#   'gf_0k': [-0.4105, -0.1764]},
#  'BHN4/BH': {'chemical_loop': ['1.5 H2 + 0.25 BHN4 -> H3N + 0.25 BH',
#    '0.5 N2 + 0.25 BH -> 0.25 BHN4'],
#   'rxn_energy': [0.1908, -0.3585],
#   'gf_sisso': [-0.2351, 0.0117],
#   'gf_0k': [-0.4105, -0.0747]},
#  'BHN4/B5H9': {'chemical_loop': ['1.6 H2 + 0.25 BHN4 -> H3N + 0.05 B5H9',
#    '0.5 N2 + 0.05 B5H9 -> 0.1 H2 + 0.25 BHN4'],
#   'rxn_energy': [0.1479, -0.3156],
#   'gf_sisso': [-0.2351, -0.0529],
#   'gf_0k': [-0.4105, -0.1644]},
#  'BHN4/B5H8': {'chemical_loop': ['1.575 H2 + 0.25 BHN4 -> H3N + 0.05 B5H8',
#    '0.5 N2 + 0.05 B5H8 -> 0.075 H2 + 0.25 BHN4'],
#   'rxn_energy': [0.1558, -0.3235],
#   'gf_sisso': [-0.2351, -0.0448],
#   'gf_0k': [-0.4105, -0.1526]},
#  'BHN4/B5H11': {'chemical_loop': ['1.65 H2 + 0.25 BHN4 -> H3N + 0.05 B5H11',
#    '0.5 N2 + 0.05 B5H11 -> 0.15 H2 + 0.25 BHN4'],
#   'rxn_energy': [0.1539, -0.3216],
#   'gf_sisso': [-0.2351, -0.0388],
#   'gf_0k': [-0.4105, -0.1587]},
#  'B3H7N/BH3': {'chemical_loop': ['2.5 H2 + B3H7N -> H3N + 3 BH3',
#    '0.5 N2 + 3 BH3 -> H2 + B3H7N'],
#   'rxn_energy': [-3.3854, 3.2177],
#   'gf_sisso': [0.2589, -0.0308],
#   'gf_0k': [0.1309, -0.1643]},
#  'B3H7N/B2H5': {'chemical_loop': ['1.75 H2 + B3H7N -> H3N + 1.5 B2H5',
#    '0.5 N2 + 1.5 B2H5 -> 0.25 H2 + B3H7N'],
#   'rxn_energy': [-3.5365, 3.3688],
#   'gf_sisso': [0.2589, -0.0496],
#   'gf_0k': [0.1309, -0.1793]},
#  'BH2N/BH3': {'chemical_loop': ['2 H2 + BH2N -> H3N + BH3',
#    '0.5 N2 + BH3 -> 0.5 H2 + BH2N'],
#   'rxn_energy': [1.9957, -2.1634],
#   'gf_sisso': [-0.5717, -0.0308],
#   'gf_0k': [-0.7184, -0.1643]},
#  'BH2N/B2H5': {'chemical_loop': ['1.75 H2 + BH2N -> H3N + 0.5 B2H5',
#    '0.5 N2 + 0.5 B2H5 -> 0.25 H2 + BH2N'],
#   'rxn_energy': [1.9453, -2.113],
#   'gf_sisso': [-0.5717, -0.0496],
#   'gf_0k': [-0.7184, -0.1793]},
#  'BH2N/B5H11': {'chemical_loop': ['1.6 H2 + BH2N -> H3N + 0.2 B5H11',
#    '0.5 N2 + 0.2 B5H11 -> 0.1 H2 + BH2N'],
#   'rxn_energy': [1.9948, -2.1626],
#   'gf_sisso': [-0.5717, -0.0388],
#   'gf_0k': [-0.7184, -0.1587]},
#  'B6H10N/BH3': {'chemical_loop': ['5.5 H2 + B6H10N -> H3N + 6 BH3',
#    '0.5 N2 + 6 BH3 -> 4 H2 + B6H10N'],
#   'rxn_energy': [3.7578, -3.9255],
#   'gf_sisso': [-0.2744, -0.0308],
#   'gf_0k': [-0.393, -0.1643]},
#  'B6H10N/B2H5': {'chemical_loop': ['4 H2 + B6H10N -> H3N + 3 B2H5',
#    '0.5 N2 + 3 B2H5 -> 2.5 H2 + B6H10N'],
#   'rxn_energy': [3.4555, -3.6233],
#   'gf_sisso': [-0.2744, -0.0496],
#   'gf_0k': [-0.393, -0.1793]},
#  'B6H10N/B3H5': {'chemical_loop': ['1.5 H2 + B6H10N -> H3N + 2 B3H5',
#    '0.5 N2 + 2 B3H5 -> B6H10N'],
#   'rxn_energy': [3.541, -3.7088],
#   'gf_sisso': [-0.2744, -0.0598],
#   'gf_0k': [-0.393, -0.1731]},
#  'B6H10N/B5H9': {'chemical_loop': ['1.9 H2 + B6H10N -> H3N + 1.2 B5H9',
#    '0.5 N2 + 1.2 B5H9 -> 0.4 H2 + B6H10N'],
#   'rxn_energy': [3.6079, -3.7756],
#   'gf_sisso': [-0.2744, -0.0529],
#   'gf_0k': [-0.393, -0.1644]},
#  'B6H10N/B5H11': {'chemical_loop': ['3.1 H2 + B6H10N -> H3N + 1.2 B5H11',
#    '0.5 N2 + 1.2 B5H11 -> 1.6 H2 + B6H10N'],
#   'rxn_energy': [3.7527, -3.9204],
#   'gf_sisso': [-0.2744, -0.0388],
#   'gf_0k': [-0.393, -0.1587]},
#  'B9H11N4/B3H4': {'chemical_loop': ['1.625 H2 + 0.25 B9H11N4 -> H3N + 0.75 B3H4',
#    '0.5 N2 + 0.75 B3H4 -> 0.125 H2 + 0.25 B9H11N4'],
#   'rxn_energy': [0.2281, -0.3958],
#   'gf_sisso': [-0.0192, 0.0534],
#   'gf_0k': [-0.1361, -0.0201]},
#  'B9H11N4/BH3': {'chemical_loop': ['3.5 H2 + 0.25 B9H11N4 -> H3N + 2.25 BH3',
#    '0.5 N2 + 2.25 BH3 -> 2 H2 + 0.25 B9H11N4'],
#   'rxn_energy': [-0.3298, 0.162],
#   'gf_sisso': [-0.0192, -0.0308],
#   'gf_0k': [-0.1361, -0.1643]},
#  'B9H11N4/B7H10': {'chemical_loop': ['1.732 H2 + 0.25 B9H11N4 -> H3N + 0.3214 B7H10',
#    '0.5 N2 + 0.3214 B7H10 -> 0.2321 H2 + 0.25 B9H11N4'],
#   'rxn_energy': [-0.3094, 0.1417],
#   'gf_sisso': [-0.0192, -0.047],
#   'gf_0k': [-0.1361, -0.1549]},
#  'B9H11N4/B5H7': {'chemical_loop': ['1.7 H2 + 0.25 B9H11N4 -> H3N + 0.45 B5H7',
#    '0.5 N2 + 0.45 B5H7 -> 0.2 H2 + 0.25 B9H11N4'],
#   'rxn_energy': [-0.4504, 0.2826],
#   'gf_sisso': [-0.0192, -0.0737],
#   'gf_0k': [-0.1361, -0.1872]},
#  'B9H11N4/B10H13': {'chemical_loop': ['1.588 H2 + 0.25 B9H11N4 -> H3N + 0.225 B10H13',
#    '0.5 N2 + 0.225 B10H13 -> 0.0875 H2 + 0.25 B9H11N4'],
#   'rxn_energy': [-0.462, 0.2943],
#   'gf_sisso': [-0.0192, -0.0791],
#   'gf_0k': [-0.1361, -0.1827]},
#  'B9H11N4/B2H5': {'chemical_loop': ['2.938 H2 + 0.25 B9H11N4 -> H3N + 1.125 B2H5',
#    '0.5 N2 + 1.125 B2H5 -> 1.437 H2 + 0.25 B9H11N4'],
#   'rxn_energy': [-0.4431, 0.2754],
#   'gf_sisso': [-0.0192, -0.0496],
#   'gf_0k': [-0.1361, -0.1793]},
#  'B9H11N4/B2H3': {'chemical_loop': ['1.813 H2 + 0.25 B9H11N4 -> H3N + 1.125 B2H3',
#    '0.5 N2 + 1.125 B2H3 -> 0.3125 H2 + 0.25 B9H11N4'],
#   'rxn_energy': [-0.3088, 0.1411],
#   'gf_sisso': [-0.0192, -0.0456],
#   'gf_0k': [-0.1361, -0.1516]},
#  'B9H11N4/B9H11': {'chemical_loop': ['1.5 H2 + 0.25 B9H11N4 -> H3N + 0.25 B9H11',
#    '0.5 N2 + 0.25 B9H11 -> 0.25 B9H11N4'],
#   'rxn_energy': [-0.4964, 0.3287],
#   'gf_sisso': [-0.0192, -0.0888],
#   'gf_0k': [-0.1361, -0.189]},
#  'B9H11N4/B3H5': {'chemical_loop': ['2 H2 + 0.25 B9H11N4 -> H3N + 0.75 B3H5',
#    '0.5 N2 + 0.75 B3H5 -> 0.5 H2 + 0.25 B9H11N4'],
#   'rxn_energy': [-0.4111, 0.2433],
#   'gf_sisso': [-0.0192, -0.0598],
#   'gf_0k': [-0.1361, -0.1731]},
#  'B9H11N4/B13H19': {'chemical_loop': ['1.769 H2 + 0.25 B9H11N4 -> H3N + 0.1731 B13H19',
#    '0.5 N2 + 0.1731 B13H19 -> 0.2692 H2 + 0.25 B9H11N4'],
#   'rxn_energy': [-0.3509, 0.1831],
#   'gf_sisso': [-0.0192, -0.0539],
#   'gf_0k': [-0.1361, -0.16]},
#  'B9H11N4/B4H5': {'chemical_loop': ['1.531 H2 + 0.25 B9H11N4 -> H3N + 0.5625 B4H5',
#    '0.5 N2 + 0.5625 B4H5 -> 0.03125 H2 + 0.25 B9H11N4'],
#   'rxn_energy': [-0.4556, 0.2879],
#   'gf_sisso': [-0.0192, -0.0796],
#   'gf_0k': [-0.1361, -0.1764]},
#  'B9H11N4/B5H9': {'chemical_loop': ['2.15 H2 + 0.25 B9H11N4 -> H3N + 0.45 B5H9',
#    '0.5 N2 + 0.45 B5H9 -> 0.65 H2 + 0.25 B9H11N4'],
#   'rxn_energy': [-0.386, 0.2183],
#   'gf_sisso': [-0.0192, -0.0529],
#   'gf_0k': [-0.1361, -0.1644]},
#  'B9H11N4/B5H8': {'chemical_loop': ['1.925 H2 + 0.25 B9H11N4 -> H3N + 0.45 B5H8',
#    '0.5 N2 + 0.45 B5H8 -> 0.425 H2 + 0.25 B9H11N4'],
#   'rxn_energy': [-0.3145, 0.1468],
#   'gf_sisso': [-0.0192, -0.0448],
#   'gf_0k': [-0.1361, -0.1526]},
#  'B9H11N4/B5H11': {'chemical_loop': ['2.6 H2 + 0.25 B9H11N4 -> H3N + 0.45 B5H11',
#    '0.5 N2 + 0.45 B5H11 -> 1.1 H2 + 0.25 B9H11N4'],
#   'rxn_energy': [-0.3317, 0.164],
#   'gf_sisso': [-0.0192, -0.0388],
#   'gf_0k': [-0.1361, -0.1587]},
#  'B3H5N3/BH3': {'chemical_loop': ['2.167 H2 + 0.3333 B3H5N3 -> H3N + BH3',
#    '0.5 N2 + BH3 -> 0.6667 H2 + 0.3333 B3H5N3'],
#   'rxn_energy': [2.0921, -2.2599],
#   'gf_sisso': [-0.6499, -0.0308],
#   'gf_0k': [-0.7783, -0.1643]},
#  'B3H5N3/B2H5': {'chemical_loop': ['1.917 H2 + 0.3333 B3H5N3 -> H3N + 0.5 B2H5',
#    '0.5 N2 + 0.5 B2H5 -> 0.4167 H2 + 0.3333 B3H5N3'],
#   'rxn_energy': [2.0418, -2.2095],
#   'gf_sisso': [-0.6499, -0.0496],
#   'gf_0k': [-0.7783, -0.1793]},
#  'B3H5N3/B3H5': {'chemical_loop': ['1.5 H2 + 0.3333 B3H5N3 -> H3N + 0.3333 B3H5',
#    '0.5 N2 + 0.3333 B3H5 -> 0.3333 B3H5N3'],
#   'rxn_energy': [2.056, -2.2237],
#   'gf_sisso': [-0.6499, -0.0598],
#   'gf_0k': [-0.7783, -0.1731]},
#  'B3H5N3/B5H9': {'chemical_loop': ['1.567 H2 + 0.3333 B3H5N3 -> H3N + 0.2 B5H9',
#    '0.5 N2 + 0.2 B5H9 -> 0.06667 H2 + 0.3333 B3H5N3'],
#   'rxn_energy': [2.0672, -2.2349],
#   'gf_sisso': [-0.6499, -0.0529],
#   'gf_0k': [-0.7783, -0.1644]},
#  'B3H5N3/B5H11': {'chemical_loop': ['1.767 H2 + 0.3333 B3H5N3 -> H3N + 0.2 B5H11',
#    '0.5 N2 + 0.2 B5H11 -> 0.2667 H2 + 0.3333 B3H5N3'],
#   'rxn_energy': [2.0913, -2.259],
#   'gf_sisso': [-0.6499, -0.0388],
#   'gf_0k': [-0.7783, -0.1587]},
#  'B5H11N2/BH3': {'chemical_loop': ['2.5 H2 + 0.5 B5H11N2 -> H3N + 2.5 BH3',
#    '0.5 N2 + 2.5 BH3 -> H2 + 0.5 B5H11N2'],
#   'rxn_energy': [1.2161, -1.3838],
#   'gf_sisso': [-0.188, -0.0308],
#   'gf_0k': [-0.3371, -0.1643]},
#  'B5H11N2/B2H5': {'chemical_loop': ['1.875 H2 + 0.5 B5H11N2 -> H3N + 1.25 B2H5',
#    '0.5 N2 + 1.25 B2H5 -> 0.375 H2 + 0.5 B5H11N2'],
#   'rxn_energy': [1.0901, -1.2579],
#   'gf_sisso': [-0.188, -0.0496],
#   'gf_0k': [-0.3371, -0.1793]},
#  'B5H11N2/B5H11': {'chemical_loop': ['1.5 H2 + 0.5 B5H11N2 -> H3N + 0.5 B5H11',
#    '0.5 N2 + 0.5 B5H11 -> 0.5 B5H11N2'],
#   'rxn_energy': [1.214, -1.3817],
#   'gf_sisso': [-0.188, -0.0388],
#   'gf_0k': [-0.3371, -0.1587]},
#  'B5H9N/BH3': {'chemical_loop': ['4.5 H2 + B5H9N -> H3N + 5 BH3',
#    '0.5 N2 + 5 BH3 -> 3 H2 + B5H9N'],
#   'rxn_energy': [2.1654, -2.3331],
#   'gf_sisso': [-0.1966, -0.0308],
#   'gf_0k': [-0.3309, -0.1643]},
#  'B5H9N/B2H5': {'chemical_loop': ['3.25 H2 + B5H9N -> H3N + 2.5 B2H5',
#    '0.5 N2 + 2.5 B2H5 -> 1.75 H2 + B5H9N'],
#   'rxn_energy': [1.9135, -2.0813],
#   'gf_sisso': [-0.1966, -0.0496],
#   'gf_0k': [-0.3309, -0.1793]},
#  'B5H9N/B5H9': {'chemical_loop': ['1.5 H2 + B5H9N -> H3N + B5H9',
#    '0.5 N2 + B5H9 -> B5H9N'],
#   'rxn_energy': [2.0405, -2.2082],
#   'gf_sisso': [-0.1966, -0.0529],
#   'gf_0k': [-0.3309, -0.1644]},
#  'B5H9N/B5H11': {'chemical_loop': ['2.5 H2 + B5H9N -> H3N + B5H11',
#    '0.5 N2 + B5H11 -> H2 + B5H9N'],
#   'rxn_energy': [2.1612, -2.3289],
#   'gf_sisso': [-0.1966, -0.0388],
#   'gf_0k': [-0.3309, -0.1587]},
#  'Ca16HN8/CaH2': {'chemical_loop': ['3.438 H2 + 0.125 Ca16HN8 -> H3N + 2 CaH2',
#    '0.5 N2 + 2 CaH2 -> 1.937 H2 + 0.125 Ca16HN8'],
#   'rxn_energy': [-0.9993, 0.8316],
#   'gf_sisso': [-0.7546, -0.5316],
#   'gf_0k': [-0.8538, -0.674]},
#  'Ca16HN8/CaH3': {'chemical_loop': ['4.438 H2 + 0.125 Ca16HN8 -> H3N + 2 CaH3',
#    '0.5 N2 + 2 CaH3 -> 2.937 H2 + 0.125 Ca16HN8'],
#   'rxn_energy': [1.921, -2.0887],
#   'gf_sisso': [-0.7546, -0.0337],
#   'gf_0k': [-0.8538, -0.2008]},
#  'Ca8H3N4/CaH2': {'chemical_loop': ['3.125 H2 + 0.25 Ca8H3N4 -> H3N + 2 CaH2',
#    '0.5 N2 + 2 CaH2 -> 1.625 H2 + 0.25 Ca8H3N4'],
#   'rxn_energy': [-0.5762, 0.4085],
#   'gf_sisso': [-0.7417, -0.5316],
#   'gf_0k': [-0.8608, -0.674]},
#  'Ca8H3N4/CaH3': {'chemical_loop': ['4.125 H2 + 0.25 Ca8H3N4 -> H3N + 2 CaH3',
#    '0.5 N2 + 2 CaH3 -> 2.625 H2 + 0.25 Ca8H3N4'],
#   'rxn_energy': [2.3441, -2.5118],
#   'gf_sisso': [-0.7417, -0.0337],
#   'gf_0k': [-0.8608, -0.2008]},
#  'CaHN/CaH2': {'chemical_loop': ['2 H2 + CaHN -> H3N + CaH2',
#    '0.5 N2 + CaH2 -> 0.5 H2 + CaHN'],
#   'rxn_energy': [0.3047, -0.4725],
#   'gf_sisso': [-0.6891, -0.5316],
#   'gf_0k': [-0.8558, -0.674]},
#  'CaHN/CaH3': {'chemical_loop': ['2.5 H2 + CaHN -> H3N + CaH3',
#    '0.5 N2 + CaH3 -> H2 + CaHN'],
#   'rxn_energy': [1.7649, -1.9326],
#   'gf_sisso': [-0.6891, -0.0337],
#   'gf_0k': [-0.8558, -0.2008]},
#  'Ca2HN/CaH2': {'chemical_loop': ['3 H2 + Ca2HN -> H3N + 2 CaH2',
#    '0.5 N2 + 2 CaH2 -> 1.5 H2 + Ca2HN'],
#   'rxn_energy': [-0.1705, 0.0027],
#   'gf_sisso': [-0.7968, -0.5316],
#   'gf_0k': [-0.9224, -0.674]},
#  'Ca2HN/CaH3': {'chemical_loop': ['4 H2 + Ca2HN -> H3N + 2 CaH3',
#    '0.5 N2 + 2 CaH3 -> 2.5 H2 + Ca2HN'],
#   'rxn_energy': [2.7498, -2.9175],
#   'gf_sisso': [-0.7968, -0.0337],
#   'gf_0k': [-0.9224, -0.2008]},
#  'PHN2/PH3': {'chemical_loop': ['2 H2 + 0.5 PHN2 -> H3N + 0.5 PH3',
#    '0.5 N2 + 0.5 PH3 -> 0.5 H2 + 0.5 PHN2'],
#   'rxn_energy': [0.6959, -0.8636],
#   'gf_sisso': [-0.3516, 0.0802],
#   'gf_0k': [-0.5523, 0.0293]},
#  'NaHN/NaH': {'chemical_loop': ['1.5 H2 + NaHN -> H3N + NaH',
#    '0.5 N2 + NaH -> NaHN'],
#   'rxn_energy': [-1.8284, 1.6607],
#   'gf_sisso': [0.4594, -0.1412],
#   'gf_0k': [0.3033, -0.2746]},
#  'H4S4N/H3S': {'chemical_loop': ['5.5 H2 + H4S4N -> H3N + 4 H3S',
#    '0.5 N2 + 4 H3S -> 4 H2 + H4S4N'],
#   'rxn_energy': [1.9433, -2.111],
#   'gf_sisso': [-0.3971, -0.0914],
#   'gf_0k': [-0.4518, -0.2204]},
#  'H4S4N/H2S': {'chemical_loop': ['3.5 H2 + H4S4N -> 4 H2S + H3N',
#    '0.5 N2 + 4 H2S -> 2 H2 + H4S4N'],
#   'rxn_energy': [2.0211, -2.1888],
#   'gf_sisso': [-0.3971, -0.1154],
#   'gf_0k': [-0.4518, -0.3164]},
#  'H8S5N2/H3S': {'chemical_loop': ['3.25 H2 + 0.5 H8S5N2 -> H3N + 2.5 H3S',
#    '0.5 N2 + 2.5 H3S -> 1.75 H2 + 0.5 H8S5N2'],
#   'rxn_energy': [1.5188, -1.6866],
#   'gf_sisso': [-0.3468, -0.0914],
#   'gf_0k': [-0.4766, -0.2204]},
#  'H8S5N2/H2S': {'chemical_loop': ['2 H2 + 0.5 H8S5N2 -> 2.5 H2S + H3N',
#    '0.5 N2 + 2.5 H2S -> 0.5 H2 + 0.5 H8S5N2'],
#   'rxn_energy': [1.5675, -1.7352],
#   'gf_sisso': [-0.3468, -0.1154],
#   'gf_0k': [-0.4766, -0.3164]},
#  'HS8N/H3S': {'chemical_loop': ['HS8N + 13 H2 -> H3N + 8 H3S',
#    '0.5 N2 + 8 H3S -> HS8N + 11.5 H2'],
#   'rxn_energy': [-3.6877, 3.52],
#   'gf_sisso': [0.0594, -0.0914],
#   'gf_0k': [0.0287, -0.2204]},
#  'HS8N/H2S': {'chemical_loop': ['HS8N + 9 H2 -> 8 H2S + H3N',
#    '0.5 N2 + 8 H2S -> HS8N + 7.5 H2'],
#   'rxn_energy': [-3.532, 3.3643],
#   'gf_sisso': [0.0594, -0.1154],
#   'gf_0k': [0.0287, -0.3164]},
#  'HSN/H3S': {'chemical_loop': ['HSN + 2.5 H2 -> H3N + H3S',
#    '0.5 N2 + H3S -> HSN + H2'],
#   'rxn_energy': [-0.9556, 0.7879],
#   'gf_sisso': [0.1407, -0.0914],
#   'gf_0k': [-0.0002, -0.2204]},
#  'HSN/H2S': {'chemical_loop': ['HSN + 2 H2 -> H2S + H3N',
#    '0.5 N2 + H2S -> HSN + 0.5 H2'],
#   'rxn_energy': [-0.9362, 0.7685],
#   'gf_sisso': [0.1407, -0.1154],
#   'gf_0k': [-0.0002, -0.3164]},
#  'HS9N/H3S': {'chemical_loop': ['HS9N + 14.5 H2 -> H3N + 9 H3S',
#    '0.5 N2 + 9 H3S -> HS9N + 13 H2'],
#   'rxn_energy': [-4.0302, 3.8625],
#   'gf_sisso': [0.0519, -0.0914],
#   'gf_0k': [0.0259, -0.2204]},
#  'HS9N/H2S': {'chemical_loop': ['HS9N + 10 H2 -> 9 H2S + H3N',
#    '0.5 N2 + 9 H2S -> HS9N + 8.5 H2'],
#   'rxn_energy': [-3.8551, 3.6873],
#   'gf_sisso': [0.0519, -0.1154],
#   'gf_0k': [0.0259, -0.3164]},
#  'HS7N/H3S': {'chemical_loop': ['HS7N + 11.5 H2 -> H3N + 7 H3S',
#    '0.5 N2 + 7 H3S -> HS7N + 10 H2'],
#   'rxn_energy': [-3.0505, 2.8828],
#   'gf_sisso': [0.0359, -0.0914],
#   'gf_0k': [0.0013, -0.2204]},
#  'HS7N/H2S': {'chemical_loop': ['HS7N + 8 H2 -> 7 H2S + H3N',
#    '0.5 N2 + 7 H2S -> HS7N + 6.5 H2'],
#   'rxn_energy': [-2.9143, 2.7466],
#   'gf_sisso': [0.0359, -0.1154],
#   'gf_0k': [0.0013, -0.3164]},
#  'HS3N/H3S': {'chemical_loop': ['HS3N + 5.5 H2 -> H3N + 3 H3S',
#    '0.5 N2 + 3 H3S -> HS3N + 4 H2'],
#   'rxn_energy': [-1.5212, 1.3535],
#   'gf_sisso': [0.0513, -0.0914],
#   'gf_0k': [-0.0285, -0.2204]},
#  'HS3N/H2S': {'chemical_loop': ['HS3N + 4 H2 -> 3 H2S + H3N',
#    '0.5 N2 + 3 H2S -> HS3N + 2.5 H2'],
#   'rxn_energy': [-1.4629, 1.2951],
#   'gf_sisso': [0.0513, -0.1154],
#   'gf_0k': [-0.0285, -0.3164]},
#  'Ti20H2N17/TiH2': {'chemical_loop': ['2.618 H2 + 0.05882 Ti20H2N17 -> H3N + 1.176 TiH2',
#    '0.5 N2 + 1.176 TiH2 -> 1.118 H2 + 0.05882 Ti20H2N17'],
#   'rxn_energy': [1.94, -2.1078],
#   'gf_sisso': [-1.5896, -0.4361],
#   'gf_0k': [-1.7439, -0.6029]},
#  'Ti20H2N17/TiH': {'chemical_loop': ['2.029 H2 + 0.05882 Ti20H2N17 -> H3N + 1.176 TiH',
#    '0.5 N2 + 1.176 TiH -> 0.5294 H2 + 0.05882 Ti20H2N17'],
#   'rxn_energy': [2.7151, -2.8828],
#   'gf_sisso': [-1.5896, -0.3247],
#   'gf_0k': [-1.7439, -0.4505]},
#  'Ti20H2N17/Ti2H3': {'chemical_loop': ['2.324 H2 + 0.05882 Ti20H2N17 -> H3N + 0.5882 Ti2H3',
#    '0.5 N2 + 0.5882 Ti2H3 -> 0.8235 H2 + 0.05882 Ti20H2N17'],
#   'rxn_energy': [2.3492, -2.5169],
#   'gf_sisso': [-1.5896, -0.3842],
#   'gf_0k': [-1.7439, -0.5335]},
#  'Ti20H2N17/Ti4H7': {'chemical_loop': ['2.471 H2 + 0.05882 Ti20H2N17 -> H3N + 0.2941 Ti4H7',
#    '0.5 N2 + 0.2941 Ti4H7 -> 0.9706 H2 + 0.05882 Ti20H2N17'],
#   'rxn_energy': [2.1377, -2.3054],
#   'gf_sisso': [-1.5896, -0.4146],
#   'gf_0k': [-1.7439, -0.573]},
#  'Ti20H2N17/Ti2H': {'chemical_loop': ['1.735 H2 + 0.05882 Ti20H2N17 -> H3N + 0.5882 Ti2H',
#    '0.5 N2 + 0.5882 Ti2H -> 0.2353 H2 + 0.05882 Ti20H2N17'],
#   'rxn_energy': [3.187, -3.3547],
#   'gf_sisso': [-1.5896, -0.1655],
#   'gf_0k': [-1.7439, -0.2563]},
#  'Ti20H2N17/Ti4H3': {'chemical_loop': ['1.882 H2 + 0.05882 Ti20H2N17 -> H3N + 0.2941 Ti4H3',
#    '0.5 N2 + 0.2941 Ti4H3 -> 0.3824 H2 + 0.05882 Ti20H2N17'],
#   'rxn_energy': [2.9912, -3.1589],
#   'gf_sisso': [-1.5896, -0.237],
#   'gf_0k': [-1.7439, -0.3465]},
#  'Ti20H2N17/Ti4H5': {'chemical_loop': ['2.176 H2 + 0.05882 Ti20H2N17 -> H3N + 0.2941 Ti4H5',
#    '0.5 N2 + 0.2941 Ti4H5 -> 0.6765 H2 + 0.05882 Ti20H2N17'],
#   'rxn_energy': [2.5437, -2.7114],
#   'gf_sisso': [-1.5896, -0.3534],
#   'gf_0k': [-1.7439, -0.4917]},
#  'Si3H9N/SiH4': {'chemical_loop': ['3 H2 + Si3H9N -> H3N + 3 SiH4',
#    '0.5 N2 + 3 SiH4 -> 1.5 H2 + Si3H9N'],
#   'rxn_energy': [3.4072, -3.5749],
#   'gf_sisso': [-0.1387, 0.1181],
#   'gf_0k': [-0.2662, -0.1307]},
#  'Si3H9N/SiH8': {'chemical_loop': ['9 H2 + Si3H9N -> H3N + 3 SiH8',
#    '0.5 N2 + 3 SiH8 -> 7.5 H2 + Si3H9N'],
#   'rxn_energy': [1.6572, -1.8249],
#   'gf_sisso': [-0.1387, 0.0008],
#   'gf_0k': [-0.2662, -0.1428]},
#  'Si12HN8/Si3H': {'chemical_loop': ['1.688 H2 + 0.125 Si12HN8 -> H3N + 0.5 Si3H',
#    '0.5 N2 + 0.5 Si3H -> 0.1875 H2 + 0.125 Si12HN8'],
#   'rxn_energy': [0.9443, -1.112],
#   'gf_sisso': [-0.4096, 0.0184],
#   'gf_0k': [-0.509, -0.0091]},
#  'Si12HN8/SiH': {'chemical_loop': ['2.188 H2 + 0.125 Si12HN8 -> H3N + 1.5 SiH',
#    '0.5 N2 + 1.5 SiH -> 0.6875 H2 + 0.125 Si12HN8'],
#   'rxn_energy': [0.9288, -1.0966],
#   'gf_sisso': [-0.4096, 0.0071],
#   'gf_0k': [-0.509, -0.0539]},
#  'Si12HN8/SiH4': {'chemical_loop': ['4.438 H2 + 0.125 Si12HN8 -> H3N + 1.5 SiH4',
#    '0.5 N2 + 1.5 SiH4 -> 2.937 H2 + 0.125 Si12HN8'],
#   'rxn_energy': [1.7931, -1.9608],
#   'gf_sisso': [-0.4096, 0.1181],
#   'gf_0k': [-0.509, -0.1307]},
#  'Si12HN8/SiH2': {'chemical_loop': ['2.938 H2 + 0.125 Si12HN8 -> H3N + 1.5 SiH2',
#    '0.5 N2 + 1.5 SiH2 -> 1.437 H2 + 0.125 Si12HN8'],
#   'rxn_energy': [0.9983, -1.166],
#   'gf_sisso': [-0.4096, 0.0202],
#   'gf_0k': [-0.509, -0.0687]},
#  'Si12HN8/SiH8': {'chemical_loop': ['7.437 H2 + 0.125 Si12HN8 -> H3N + 1.5 SiH8',
#    '0.5 N2 + 1.5 SiH8 -> 5.937 H2 + 0.125 Si12HN8'],
#   'rxn_energy': [0.9181, -1.0858],
#   'gf_sisso': [-0.4096, 0.0008],
#   'gf_0k': [-0.509, -0.1428]},
#  'MgHN/MgH2': {'chemical_loop': ['2 H2 + MgHN -> H3N + MgH2',
#    '0.5 N2 + MgH2 -> 0.5 H2 + MgHN'],
#   'rxn_energy': [1.1492, -1.3169],
#   'gf_sisso': [-0.5893, -0.1504],
#   'gf_0k': [-0.7473, -0.2944]},
#  'MgHN/MgH3': {'chemical_loop': ['2.5 H2 + MgHN -> H3N + MgH3',
#    '0.5 N2 + MgH3 -> H2 + MgHN'],
#   'rxn_energy': [3.1309, -3.2986],
#   'gf_sisso': [-0.5893, 0.3827],
#   'gf_0k': [-0.7473, 0.198]},
#  'MgHN/MgH': {'chemical_loop': ['1.5 H2 + MgHN -> H3N + MgH',
#    '0.5 N2 + MgH -> MgHN'],
#   'rxn_energy': [2.0383, -2.2061],
#   'gf_sisso': [-0.5893, 0.219],
#   'gf_0k': [-0.7473, 0.1076]},
#  'KH2N/KH3': {'chemical_loop': ['2 H2 + KH2N -> H3N + KH3',
#    '0.5 N2 + KH3 -> 0.5 H2 + KH2N'],
#   'rxn_energy': [4.8281, -4.9958],
#   'gf_sisso': [-0.2605, 0.9885],
#   'gf_0k': [-0.4352, 0.8316]},
#  'Zr10HN8/ZrH': {'chemical_loop': ['2.062 H2 + 0.125 Zr10HN8 -> H3N + 1.25 ZrH',
#    '0.5 N2 + 1.25 ZrH -> 0.5625 H2 + 0.125 Zr10HN8'],
#   'rxn_energy': [2.3869, -2.5547],
#   'gf_sisso': [-1.4796, -0.3838],
#   'gf_0k': [-1.626, -0.5021]},
#  'Zr10HN8/ZrH3': {'chemical_loop': ['3.313 H2 + 0.125 Zr10HN8 -> H3N + 1.25 ZrH3',
#    '0.5 N2 + 1.25 ZrH3 -> 1.813 H2 + 0.125 Zr10HN8'],
#   'rxn_energy': [2.3019, -2.4696],
#   'gf_sisso': [-1.4796, -0.2089],
#   'gf_0k': [-1.626, -0.387]},
#  'Zr10HN8/ZrH2': {'chemical_loop': ['2.688 H2 + 0.125 Zr10HN8 -> H3N + 1.25 ZrH2',
#    '0.5 N2 + 1.25 ZrH2 -> 1.187 H2 + 0.125 Zr10HN8'],
#   'rxn_energy': [1.4241, -1.5919],
#   'gf_sisso': [-1.4796, -0.5126],
#   'gf_0k': [-1.626, -0.6697]}}

# %% [markdown]
# To calculate the Gibbs reaction within a certain temperature range, we can use concurrent.futures.ProcessPoolExecutor() to solve it in parallel.

# %%
import concurrent.futures

# Define two helper functions here.
def collect_data(temp):
    print("start ", temp)
    gibbs_cl = GibbsChemicalReactionLoop(input_cl_list, temp=temp)
    gibbs_cl.normalise_to_NH3()
    print("finished ", temp)
    return {temp: gibbs_cl.parse_to_dict()}

def parser(result_list, temp_range):
    cl_data={}
    redox_pairs = list(result_list[0][temp_range[0]].keys())
    for r in redox_pairs:
        cl_data[r]={"chemical_loop": result_list[0][temp_range[0]][r]['chemical_loop'],
                    "rxn_energy": [result_list[i][t][r]['rxn_energy']  for i, t in enumerate(temp_range)],
                    "gf_sisso": [result_list[i][t][r]['gf_sisso']  for i, t in enumerate(temp_range)],
                    "gf_0k": result_list[0][temp_range[0]][r]['gf_0k']
                    }
    return cl_data

# %%
# Calculate temperature from 300 K to 800 K concurrently.

temp_range = list(range(300, 900, 100))
result_list = []
with concurrent.futures.ProcessPoolExecutor() as executor:
    results = executor.map(collect_data, temp_range)
    for result in results:
        result_list.append(result)
result_list = sorted(result_list, key=lambda d: list(d.keys()))
cl_data = parser(result_list, temp_range)
print("Number of pairs: ", len(cl_data.keys()))

# Save the results into a json file
with open("data/chemical_loop/MH_CL_binary.json",'w') as f:
    json.dump({"cl_data":cl_data, "temp": temp_range}, f, indent=2)
# Out:
# start  300
# start  400
# start  500
# start  600
# start  700start
# 800
# finished  500
# finished  600
# finished  400
# finished  300
# finished
# 800finished  700
# Number of pairs:  136
